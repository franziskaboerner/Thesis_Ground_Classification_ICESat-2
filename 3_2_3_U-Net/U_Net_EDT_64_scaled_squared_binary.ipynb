# %% [markdown]
# # EDT only, scaled+squared FI and closed labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 20:45:17.204103: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 20:45:17.771650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'edt2_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 18:38:56.173787: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.200520: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.200797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.202970: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.203197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.203394: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.628834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.628969: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.629066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 18:38:56.629151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-05 18:38:57.514651: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 156631040 exceeds 10% of free system memory.
# 2023-10-05 18:38:57.772127: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 313262080 exceeds 10% of free system memory.
# 2023-10-05 18:38:57.943195: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 156631040 exceeds 10% of free system memory.
# 2023-10-05 18:38:58.004360: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 313262080 exceeds 10% of free system memory.
# Epoch 1/50
# 2023-10-05 18:39:01.735363: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 18:39:01.801124: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 18:39:06.166858: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31402d00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 18:39:06.166880: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 18:39:06.171431: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 18:39:06.233869: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 18:39:06.274969: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 802ms/step - loss: 0.1566 - binary_io_u: 0.4835 - val_loss: 0.3341 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0556 - binary_io_u: 0.7047 - val_loss: 0.2171 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0409 - binary_io_u: 0.7441 - val_loss: 0.1785 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0341 - binary_io_u: 0.7621 - val_loss: 0.1779 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 453ms/step - loss: 0.0296 - binary_io_u: 0.7774 - val_loss: 0.1894 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0264 - binary_io_u: 0.7905 - val_loss: 0.2045 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0241 - binary_io_u: 0.7994 - val_loss: 0.2149 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0221 - binary_io_u: 0.8113 - val_loss: 0.2262 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0208 - binary_io_u: 0.8157 - val_loss: 0.2367 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0196 - binary_io_u: 0.8243 - val_loss: 0.2518 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0187 - binary_io_u: 0.8272 - val_loss: 0.2547 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0177 - binary_io_u: 0.8357 - val_loss: 0.2607 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0173 - binary_io_u: 0.8366 - val_loss: 0.2696 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0167 - binary_io_u: 0.8411 - val_loss: 0.2858 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0159 - binary_io_u: 0.8468 - val_loss: 0.2756 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0145 - binary_io_u: 0.8605 - val_loss: 0.2799 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0149 - binary_io_u: 0.8549 - val_loss: 0.2858 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0131 - binary_io_u: 0.8727 - val_loss: 0.3122 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0125 - binary_io_u: 0.8779 - val_loss: 0.2989 - val_binary_io_u: 0.0000e+00
# Epoch 20/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0123 - binary_io_u: 0.8792 - val_loss: 0.3142 - val_binary_io_u: 0.0000e+00
# Epoch 21/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0113 - binary_io_u: 0.8892 - val_loss: 0.2443 - val_binary_io_u: 0.0042
# Epoch 22/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0109 - binary_io_u: 0.8924 - val_loss: 0.2747 - val_binary_io_u: 0.0029
# Epoch 23/50
# 38/38 [==============================] - 25s 653ms/step - loss: 0.0099 - binary_io_u: 0.9030 - val_loss: 0.1205 - val_binary_io_u: 0.3524
# Epoch 24/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0098 - binary_io_u: 0.9037 - val_loss: 0.2264 - val_binary_io_u: 0.0643
# Epoch 25/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0089 - binary_io_u: 0.9135 - val_loss: 0.1517 - val_binary_io_u: 0.2582
# Epoch 26/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0079 - binary_io_u: 0.9230 - val_loss: 0.0354 - val_binary_io_u: 0.7507
# Epoch 27/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0078 - binary_io_u: 0.9234 - val_loss: 0.1767 - val_binary_io_u: 0.1712
# Epoch 28/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0074 - binary_io_u: 0.9270 - val_loss: 0.0431 - val_binary_io_u: 0.7327
# Epoch 29/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0068 - binary_io_u: 0.9333 - val_loss: 0.0867 - val_binary_io_u: 0.5090
# Epoch 30/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0062 - binary_io_u: 0.9397 - val_loss: 0.0420 - val_binary_io_u: 0.7543
# Epoch 31/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0061 - binary_io_u: 0.9401 - val_loss: 0.2338 - val_binary_io_u: 0.0562
# Epoch 32/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0057 - binary_io_u: 0.9446 - val_loss: 0.3377 - val_binary_io_u: 5.9131e-04
# Epoch 33/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0059 - binary_io_u: 0.9423 - val_loss: 0.0769 - val_binary_io_u: 0.5630
# Epoch 34/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0044 - binary_io_u: 0.9582 - val_loss: 0.0500 - val_binary_io_u: 0.7213
# Epoch 35/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0040 - binary_io_u: 0.9623 - val_loss: 0.0435 - val_binary_io_u: 0.7516
# Epoch 36/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0035 - binary_io_u: 0.9670 - val_loss: 0.0461 - val_binary_io_u: 0.7690
# Epoch 37/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0034 - binary_io_u: 0.9683 - val_loss: 0.0548 - val_binary_io_u: 0.7386
# Epoch 38/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0034 - binary_io_u: 0.9683 - val_loss: 0.0529 - val_binary_io_u: 0.7489
# Epoch 39/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0038 - binary_io_u: 0.9634 - val_loss: 0.0919 - val_binary_io_u: 0.5426
# Epoch 40/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0030 - binary_io_u: 0.9725 - val_loss: 0.0544 - val_binary_io_u: 0.7496
# Epoch 41/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0026 - binary_io_u: 0.9768 - val_loss: 0.0511 - val_binary_io_u: 0.7622
# Epoch 42/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0022 - binary_io_u: 0.9810 - val_loss: 0.0550 - val_binary_io_u: 0.7469
# Epoch 43/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0017 - binary_io_u: 0.9864 - val_loss: 0.0555 - val_binary_io_u: 0.7699
# Epoch 44/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0016 - binary_io_u: 0.9862 - val_loss: 0.0646 - val_binary_io_u: 0.7571
# Epoch 45/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0015 - binary_io_u: 0.9881 - val_loss: 0.0695 - val_binary_io_u: 0.7518
# Epoch 46/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0013 - binary_io_u: 0.9899 - val_loss: 0.0589 - val_binary_io_u: 0.7681
# Epoch 47/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0014 - binary_io_u: 0.9882 - val_loss: 0.0643 - val_binary_io_u: 0.7665
# Epoch 48/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0014 - binary_io_u: 0.9888 - val_loss: 0.0667 - val_binary_io_u: 0.7651
# Epoch 49/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0018 - binary_io_u: 0.9838 - val_loss: 0.0887 - val_binary_io_u: 0.7139
# Epoch 50/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0015 - binary_io_u: 0.9873 - val_loss: 0.0679 - val_binary_io_u: 0.7602

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt2_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.8688896
# Binary IoU = 0.8688896
# Binary IoU for class 1 = 0.7507415
# Binary IoU for class 0 = 0.98703766

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 659ms/step

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],
)

checkpoint_filepath = 'edt3_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 20:30:51.920305: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:51.925677: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:51.925808: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:51.926712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:51.926838: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:51.926950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:52.332254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:52.332390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:52.332489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:30:52.332573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 20:30:56.997048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 20:30:57.056521: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 20:31:01.425483: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31c55120 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 20:31:01.425505: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 20:31:01.428887: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 20:31:01.473217: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 20:31:01.510383: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 803ms/step - loss: 0.2400 - binary_io_u: 0.4607 - val_loss: 0.5097 - val_binary_io_u: 0.0181
# Epoch 2/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0833 - binary_io_u: 0.7778 - val_loss: 0.2841 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0623 - binary_io_u: 0.7960 - val_loss: 0.2470 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0512 - binary_io_u: 0.8065 - val_loss: 0.2503 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0431 - binary_io_u: 0.8216 - val_loss: 0.2664 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0373 - binary_io_u: 0.8325 - val_loss: 0.2868 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0348 - binary_io_u: 0.8300 - val_loss: 0.3118 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0316 - binary_io_u: 0.8385 - val_loss: 0.3307 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0292 - binary_io_u: 0.8445 - val_loss: 0.3521 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0275 - binary_io_u: 0.8478 - val_loss: 0.3713 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0255 - binary_io_u: 0.8571 - val_loss: 0.3711 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0236 - binary_io_u: 0.8644 - val_loss: 0.3708 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0235 - binary_io_u: 0.8602 - val_loss: 0.3733 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0238 - binary_io_u: 0.8567 - val_loss: 0.3761 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0220 - binary_io_u: 0.8652 - val_loss: 0.4088 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0203 - binary_io_u: 0.8743 - val_loss: 0.4207 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0195 - binary_io_u: 0.8785 - val_loss: 0.4421 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0191 - binary_io_u: 0.8794 - val_loss: 0.4500 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0185 - binary_io_u: 0.8818 - val_loss: 0.3456 - val_binary_io_u: 0.0000e+00
# Epoch 20/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0174 - binary_io_u: 0.8896 - val_loss: 0.4919 - val_binary_io_u: 0.0000e+00
# Epoch 21/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0163 - binary_io_u: 0.8957 - val_loss: 0.2649 - val_binary_io_u: 0.0022
# Epoch 22/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0154 - binary_io_u: 0.9010 - val_loss: 0.3979 - val_binary_io_u: 0.0000e+00
# Epoch 23/50
# 38/38 [==============================] - 24s 650ms/step - loss: 0.0153 - binary_io_u: 0.9008 - val_loss: 0.0464 - val_binary_io_u: 0.7459
# Epoch 24/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0137 - binary_io_u: 0.9120 - val_loss: 0.3080 - val_binary_io_u: 0.0262
# Epoch 25/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0131 - binary_io_u: 0.9156 - val_loss: 0.2529 - val_binary_io_u: 0.0834
# Epoch 26/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0121 - binary_io_u: 0.9214 - val_loss: 0.1048 - val_binary_io_u: 0.5116
# Epoch 27/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0115 - binary_io_u: 0.9256 - val_loss: 0.1872 - val_binary_io_u: 0.2730
# Epoch 28/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0105 - binary_io_u: 0.9328 - val_loss: 0.3617 - val_binary_io_u: 0.0254
# Epoch 29/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0099 - binary_io_u: 0.9365 - val_loss: 0.0650 - val_binary_io_u: 0.7064
# Epoch 30/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0093 - binary_io_u: 0.9407 - val_loss: 0.0505 - val_binary_io_u: 0.7827
# Epoch 31/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0090 - binary_io_u: 0.9422 - val_loss: 0.0574 - val_binary_io_u: 0.7827
# Epoch 32/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0090 - binary_io_u: 0.9424 - val_loss: 0.0783 - val_binary_io_u: 0.6672
# Epoch 33/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0082 - binary_io_u: 0.9471 - val_loss: 0.0913 - val_binary_io_u: 0.6440
# Epoch 34/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0074 - binary_io_u: 0.9528 - val_loss: 0.0514 - val_binary_io_u: 0.8048
# Epoch 35/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0063 - binary_io_u: 0.9603 - val_loss: 0.0663 - val_binary_io_u: 0.7707
# Epoch 36/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0063 - binary_io_u: 0.9600 - val_loss: 0.1150 - val_binary_io_u: 0.5765
# Epoch 37/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0059 - binary_io_u: 0.9632 - val_loss: 0.1048 - val_binary_io_u: 0.6230
# Epoch 38/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0056 - binary_io_u: 0.9648 - val_loss: 0.0571 - val_binary_io_u: 0.7990
# Epoch 39/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0052 - binary_io_u: 0.9676 - val_loss: 0.0702 - val_binary_io_u: 0.7571
# Epoch 40/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0054 - binary_io_u: 0.9654 - val_loss: 0.0667 - val_binary_io_u: 0.7904
# Epoch 41/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0045 - binary_io_u: 0.9722 - val_loss: 0.0651 - val_binary_io_u: 0.8073
# Epoch 42/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0037 - binary_io_u: 0.9778 - val_loss: 0.0682 - val_binary_io_u: 0.7759
# Epoch 43/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0034 - binary_io_u: 0.9798 - val_loss: 0.0751 - val_binary_io_u: 0.8146
# Epoch 44/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0032 - binary_io_u: 0.9809 - val_loss: 0.0714 - val_binary_io_u: 0.8214
# Epoch 45/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0031 - binary_io_u: 0.9816 - val_loss: 0.0749 - val_binary_io_u: 0.7809
# Epoch 46/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0027 - binary_io_u: 0.9845 - val_loss: 0.0881 - val_binary_io_u: 0.7202
# Epoch 47/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0026 - binary_io_u: 0.9849 - val_loss: 0.0704 - val_binary_io_u: 0.7990
# Epoch 48/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0025 - binary_io_u: 0.9850 - val_loss: 0.0817 - val_binary_io_u: 0.8132
# Epoch 49/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0022 - binary_io_u: 0.9874 - val_loss: 0.0885 - val_binary_io_u: 0.8116
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0021 - binary_io_u: 0.9878 - val_loss: 0.0897 - val_binary_io_u: 0.7881

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt3_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.8632352
# Binary IoU = 0.8632352
# Binary IoU for class 1 = 0.7458766
# Binary IoU for class 0 = 0.98059374

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 657ms/step

# %% [markdown]
# ## EDT4

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT4_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'edt4_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 20:48:10.216341: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.221756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.221885: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.222790: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.222916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.223027: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.631506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.631641: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.631738: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 20:48:10.631821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 20:48:15.242798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 20:48:15.303199: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 20:48:19.733642: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f5890152050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 20:48:19.733666: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 20:48:19.736967: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 20:48:19.780468: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 20:48:19.817384: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 806ms/step - loss: 0.1413 - binary_io_u: 0.6549 - val_loss: 1.7305 - val_binary_io_u: 0.0993
# Epoch 2/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0545 - binary_io_u: 0.8227 - val_loss: 0.2696 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0451 - binary_io_u: 0.8322 - val_loss: 0.2983 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0387 - binary_io_u: 0.8443 - val_loss: 0.3631 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0350 - binary_io_u: 0.8500 - val_loss: 0.3984 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0321 - binary_io_u: 0.8558 - val_loss: 0.4543 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0302 - binary_io_u: 0.8611 - val_loss: 0.4580 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0277 - binary_io_u: 0.8691 - val_loss: 0.4826 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0265 - binary_io_u: 0.8715 - val_loss: 0.4965 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0254 - binary_io_u: 0.8751 - val_loss: 0.5098 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0239 - binary_io_u: 0.8794 - val_loss: 0.5270 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0233 - binary_io_u: 0.8817 - val_loss: 0.5375 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0223 - binary_io_u: 0.8856 - val_loss: 0.5359 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0217 - binary_io_u: 0.8872 - val_loss: 0.5606 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0208 - binary_io_u: 0.8915 - val_loss: 0.5649 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0209 - binary_io_u: 0.8894 - val_loss: 0.0980 - val_binary_io_u: 0.5252
# Epoch 17/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0187 - binary_io_u: 0.9010 - val_loss: 0.6391 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0178 - binary_io_u: 0.9055 - val_loss: 0.6628 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0170 - binary_io_u: 0.9095 - val_loss: 0.4326 - val_binary_io_u: 0.0063
# Epoch 20/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0155 - binary_io_u: 0.9179 - val_loss: 0.5554 - val_binary_io_u: 5.8526e-04
# Epoch 21/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0145 - binary_io_u: 0.9227 - val_loss: 0.6203 - val_binary_io_u: 0.0000e+00
# Epoch 22/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0102 - binary_io_u: 0.9461 - val_loss: 0.0498 - val_binary_io_u: 0.8295
# Epoch 27/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0091 - binary_io_u: 0.9522 - val_loss: 0.1075 - val_binary_io_u: 0.6571
# Epoch 28/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0084 - binary_io_u: 0.9561 - val_loss: 0.2955 - val_binary_io_u: 0.2842
# Epoch 29/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0083 - binary_io_u: 0.9566 - val_loss: 0.0556 - val_binary_io_u: 0.8240
# Epoch 30/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0077 - binary_io_u: 0.9595 - val_loss: 0.1354 - val_binary_io_u: 0.5794
# Epoch 31/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0065 - binary_io_u: 0.9667 - val_loss: 0.0554 - val_binary_io_u: 0.8306
# Epoch 32/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0063 - binary_io_u: 0.9677 - val_loss: 0.0645 - val_binary_io_u: 0.8268
# Epoch 33/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0081 - binary_io_u: 0.9575 - val_loss: 0.1386 - val_binary_io_u: 0.7015
# Epoch 34/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0096 - binary_io_u: 0.9502 - val_loss: 0.1126 - val_binary_io_u: 0.6558
# Epoch 35/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0065 - binary_io_u: 0.9664 - val_loss: 0.0999 - val_binary_io_u: 0.6923
# Epoch 36/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0051 - binary_io_u: 0.9742 - val_loss: 0.2301 - val_binary_io_u: 0.4432
# Epoch 37/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0043 - binary_io_u: 0.9784 - val_loss: 0.1357 - val_binary_io_u: 0.6313
# Epoch 38/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0040 - binary_io_u: 0.9800 - val_loss: 0.1140 - val_binary_io_u: 0.6743
# Epoch 39/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0040 - binary_io_u: 0.9798 - val_loss: 0.1113 - val_binary_io_u: 0.7082
# Epoch 40/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0036 - binary_io_u: 0.9820 - val_loss: 0.1170 - val_binary_io_u: 0.6844
# Epoch 41/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0035 - binary_io_u: 0.9826 - val_loss: 0.1249 - val_binary_io_u: 0.6855
# Epoch 42/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0028 - binary_io_u: 0.9863 - val_loss: 0.0682 - val_binary_io_u: 0.8419
# Epoch 43/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0025 - binary_io_u: 0.9881 - val_loss: 0.0692 - val_binary_io_u: 0.8391
# Epoch 44/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0024 - binary_io_u: 0.9883 - val_loss: 0.0769 - val_binary_io_u: 0.8131
# Epoch 45/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0022 - binary_io_u: 0.9895 - val_loss: 0.0759 - val_binary_io_u: 0.8411
# Epoch 46/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0019 - binary_io_u: 0.9910 - val_loss: 0.0737 - val_binary_io_u: 0.8379
# Epoch 47/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0019 - binary_io_u: 0.9912 - val_loss: 0.0826 - val_binary_io_u: 0.8331
# Epoch 48/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0019 - binary_io_u: 0.9914 - val_loss: 0.1019 - val_binary_io_u: 0.7899
# Epoch 49/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0020 - binary_io_u: 0.9906 - val_loss: 0.0777 - val_binary_io_u: 0.8273
# Epoch 50/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0028 - binary_io_u: 0.9865 - val_loss: 0.0941 - val_binary_io_u: 0.8128

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt4_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.9064156
# Binary IoU = 0.9064156
# Binary IoU for class 1 = 0.8294557
# Binary IoU for class 0 = 0.98337555

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 672ms/step

# %% [markdown]
# ## EDT5

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT5_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'edt5_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 21:23:08.193920: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.200669: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.200815: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.202008: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.202149: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.202273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.618709: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.618843: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.618940: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:23:08.619018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 21:23:13.240945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 21:23:13.300560: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 21:23:17.663556: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x30622070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 21:23:17.663580: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 21:23:17.666953: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 21:23:17.710966: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 21:23:17.748255: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 802ms/step - loss: 0.1551 - binary_io_u: 0.6723 - val_loss: 1.7950 - val_binary_io_u: 0.1115
# Epoch 2/50
# 38/38 [==============================] - 24s 635ms/step - loss: 0.0625 - binary_io_u: 0.8384 - val_loss: 0.3625 - val_binary_io_u: 0.0687
# Epoch 3/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0494 - binary_io_u: 0.8517 - val_loss: 3.1706 - val_binary_io_u: 0.1413
# Epoch 4/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0423 - binary_io_u: 0.8613 - val_loss: 0.3132 - val_binary_io_u: 8.2815e-06
# Epoch 5/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0379 - binary_io_u: 0.8665 - val_loss: 0.3723 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0338 - binary_io_u: 0.8773 - val_loss: 0.4700 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0313 - binary_io_u: 0.8810 - val_loss: 0.5096 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0286 - binary_io_u: 0.8878 - val_loss: 0.5429 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0285 - binary_io_u: 0.8854 - val_loss: 0.5588 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0292 - binary_io_u: 0.8806 - val_loss: 0.6157 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0264 - binary_io_u: 0.8912 - val_loss: 0.6126 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0247 - binary_io_u: 0.8965 - val_loss: 0.6359 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0241 - binary_io_u: 0.8973 - val_loss: 0.6717 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0243 - binary_io_u: 0.8952 - val_loss: 0.6463 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0227 - binary_io_u: 0.9016 - val_loss: 0.6895 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0219 - binary_io_u: 0.9043 - val_loss: 0.7131 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0219 - binary_io_u: 0.9039 - val_loss: 0.7210 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0206 - binary_io_u: 0.9089 - val_loss: 0.7063 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0196 - binary_io_u: 0.9125 - val_loss: 0.3716 - val_binary_io_u: 0.0094
# Epoch 20/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0196 - binary_io_u: 0.9123 - val_loss: 0.0432 - val_binary_io_u: 0.8286
# Epoch 21/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0194 - binary_io_u: 0.9139 - val_loss: 0.0723 - val_binary_io_u: 0.7269
# Epoch 22/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0172 - binary_io_u: 0.9233 - val_loss: 0.7093 - val_binary_io_u: 2.0705e-06
# Epoch 23/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0177 - binary_io_u: 0.9209 - val_loss: 0.0735 - val_binary_io_u: 0.7354
# Epoch 24/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0172 - binary_io_u: 0.9229 - val_loss: 0.6121 - val_binary_io_u: 0.0038
# Epoch 25/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0161 - binary_io_u: 0.9272 - val_loss: 0.1805 - val_binary_io_u: 0.6614
# Epoch 26/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0145 - binary_io_u: 0.9352 - val_loss: 0.0494 - val_binary_io_u: 0.8419
# Epoch 27/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0145 - binary_io_u: 0.9352 - val_loss: 0.0575 - val_binary_io_u: 0.8469
# Epoch 28/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0131 - binary_io_u: 0.9412 - val_loss: 0.0826 - val_binary_io_u: 0.7979
# Epoch 29/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0127 - binary_io_u: 0.9433 - val_loss: 0.0487 - val_binary_io_u: 0.8443
# Epoch 30/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0116 - binary_io_u: 0.9480 - val_loss: 0.0826 - val_binary_io_u: 0.7487
# Epoch 31/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0107 - binary_io_u: 0.9523 - val_loss: 0.0576 - val_binary_io_u: 0.8308
# Epoch 32/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0103 - binary_io_u: 0.9542 - val_loss: 0.0718 - val_binary_io_u: 0.8236
# Epoch 33/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0102 - binary_io_u: 0.9542 - val_loss: 0.0677 - val_binary_io_u: 0.7957
# Epoch 34/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0092 - binary_io_u: 0.9593 - val_loss: 0.0812 - val_binary_io_u: 0.8252
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0099 - binary_io_u: 0.9557 - val_loss: 0.0599 - val_binary_io_u: 0.8485
# Epoch 36/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0095 - binary_io_u: 0.9579 - val_loss: 0.0559 - val_binary_io_u: 0.8343
# Epoch 37/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0094 - binary_io_u: 0.9582 - val_loss: 0.1396 - val_binary_io_u: 0.6063
# Epoch 38/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0082 - binary_io_u: 0.9638 - val_loss: 0.1592 - val_binary_io_u: 0.5881
# Epoch 39/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0070 - binary_io_u: 0.9693 - val_loss: 0.0664 - val_binary_io_u: 0.8318
# Epoch 40/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0069 - binary_io_u: 0.9693 - val_loss: 0.0577 - val_binary_io_u: 0.8594
# Epoch 41/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0064 - binary_io_u: 0.9718 - val_loss: 0.0503 - val_binary_io_u: 0.8703
# Epoch 42/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0057 - binary_io_u: 0.9751 - val_loss: 0.0591 - val_binary_io_u: 0.8619
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0053 - binary_io_u: 0.9769 - val_loss: 0.0737 - val_binary_io_u: 0.8221
# Epoch 44/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0051 - binary_io_u: 0.9780 - val_loss: 0.0802 - val_binary_io_u: 0.8301
# Epoch 45/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0052 - binary_io_u: 0.9777 - val_loss: 0.1176 - val_binary_io_u: 0.7294
# Epoch 46/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0040 - binary_io_u: 0.9831 - val_loss: 0.0589 - val_binary_io_u: 0.8653
# Epoch 47/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0049 - binary_io_u: 0.9786 - val_loss: 0.2304 - val_binary_io_u: 0.7199
# Epoch 48/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0048 - binary_io_u: 0.9794 - val_loss: 0.0655 - val_binary_io_u: 0.8486
# Epoch 49/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0038 - binary_io_u: 0.9835 - val_loss: 0.0657 - val_binary_io_u: 0.8446
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0035 - binary_io_u: 0.9850 - val_loss: 0.1024 - val_binary_io_u: 0.7833

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt5_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.904179
# Binary IoU = 0.904179
# Binary IoU for class 1 = 0.8285534
# Binary IoU for class 0 = 0.9798045

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 653ms/step

# %% [markdown]
# ## prediction images

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_squared_binary_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('edt2_sb_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 150/150 [==============================] - 10s 67ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)
# Out:
# 38/38 [==============================] - 3s 67ms/step
# (5974, 128, 128, 1)

# %%
np.savez_compressed("../Photon_IoU/all_predicted_scaled_squared_binary_EDT2_res64", pred=all_predicted)
