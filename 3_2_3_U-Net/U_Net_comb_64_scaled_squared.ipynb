# %% [markdown]
# # EDT+KDE scaled+squared FI and normal labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 20:53:33.868813: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 20:53:34.438583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][kf::2]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'comb2_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 11:22:13.783193: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:13.788070: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:13.788181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:13.788961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:13.789069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:13.789164: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:14.193310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:14.193448: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:14.193545: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:22:14.193624: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 11:22:19.001495: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 11:22:19.068595: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 11:22:23.435418: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f63215801e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 11:22:23.435438: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 11:22:23.438713: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 11:22:23.482274: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 11:22:23.519247: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 809ms/step - loss: 0.2922 - binary_io_u: 0.2368 - val_loss: 0.5836 - val_binary_io_u: 0.0480
# Epoch 2/50
# 38/38 [==============================] - 24s 633ms/step - loss: 0.1045 - binary_io_u: 0.5505 - val_loss: 0.2165 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0795 - binary_io_u: 0.5827 - val_loss: 0.3775 - val_binary_io_u: 0.0445
# Epoch 4/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0651 - binary_io_u: 0.6122 - val_loss: 0.1597 - val_binary_io_u: 0.0025
# Epoch 5/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0548 - binary_io_u: 0.6421 - val_loss: 0.1602 - val_binary_io_u: 2.8276e-04
# Epoch 6/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0456 - binary_io_u: 0.6699 - val_loss: 0.1600 - val_binary_io_u: 5.0599e-05
# Epoch 7/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0388 - binary_io_u: 0.7145 - val_loss: 0.1563 - val_binary_io_u: 1.1906e-05
# Epoch 8/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0331 - binary_io_u: 0.7391 - val_loss: 0.1532 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0284 - binary_io_u: 0.7722 - val_loss: 0.1605 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0262 - binary_io_u: 0.7787 - val_loss: 0.1648 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0259 - binary_io_u: 0.7790 - val_loss: 2.6516 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0285 - binary_io_u: 0.7368 - val_loss: 0.2278 - val_binary_io_u: 0.0015
# Epoch 13/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0216 - binary_io_u: 0.7978 - val_loss: 0.1521 - val_binary_io_u: 0.0017
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0199 - binary_io_u: 0.8106 - val_loss: 0.1597 - val_binary_io_u: 5.9230e-04
# Epoch 15/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0180 - binary_io_u: 0.8262 - val_loss: 0.1531 - val_binary_io_u: 0.0032
# Epoch 16/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0171 - binary_io_u: 0.8330 - val_loss: 0.1662 - val_binary_io_u: 0.0104
# Epoch 17/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0162 - binary_io_u: 0.8371 - val_loss: 0.1248 - val_binary_io_u: 0.0362
# Epoch 18/50
# 38/38 [==============================] - 25s 657ms/step - loss: 0.0158 - binary_io_u: 0.8375 - val_loss: 0.0448 - val_binary_io_u: 0.4795
# Epoch 19/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0142 - binary_io_u: 0.8541 - val_loss: 0.0599 - val_binary_io_u: 0.3235
# Epoch 20/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0140 - binary_io_u: 0.8527 - val_loss: 0.0783 - val_binary_io_u: 0.1819
# Epoch 21/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0135 - binary_io_u: 0.8564 - val_loss: 0.0198 - val_binary_io_u: 0.7985
# Epoch 22/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0127 - binary_io_u: 0.8621 - val_loss: 0.0190 - val_binary_io_u: 0.8034
# Epoch 23/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0122 - binary_io_u: 0.8665 - val_loss: 0.0213 - val_binary_io_u: 0.7732
# Epoch 24/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0120 - binary_io_u: 0.8689 - val_loss: 0.0209 - val_binary_io_u: 0.7755
# Epoch 25/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0115 - binary_io_u: 0.8720 - val_loss: 0.0195 - val_binary_io_u: 0.7896
# Epoch 26/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0113 - binary_io_u: 0.8734 - val_loss: 0.0232 - val_binary_io_u: 0.7623
# Epoch 27/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0112 - binary_io_u: 0.8744 - val_loss: 0.0225 - val_binary_io_u: 0.7598
# Epoch 28/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0114 - binary_io_u: 0.8712 - val_loss: 0.0244 - val_binary_io_u: 0.7188
# Epoch 29/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0104 - binary_io_u: 0.8819 - val_loss: 0.0191 - val_binary_io_u: 0.7914
# Epoch 30/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0107 - binary_io_u: 0.8767 - val_loss: 0.0201 - val_binary_io_u: 0.8034
# Epoch 31/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0109 - binary_io_u: 0.8756 - val_loss: 0.0210 - val_binary_io_u: 0.7822
# Epoch 32/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0100 - binary_io_u: 0.8851 - val_loss: 0.0178 - val_binary_io_u: 0.8163
# Epoch 33/50
# 38/38 [==============================] - 25s 651ms/step - loss: 0.0097 - binary_io_u: 0.8874 - val_loss: 0.0177 - val_binary_io_u: 0.8074
# Epoch 34/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0092 - binary_io_u: 0.8942 - val_loss: 0.0182 - val_binary_io_u: 0.8099
# Epoch 35/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0090 - binary_io_u: 0.8959 - val_loss: 0.0198 - val_binary_io_u: 0.8089
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0091 - binary_io_u: 0.8937 - val_loss: 0.0181 - val_binary_io_u: 0.8194
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0085 - binary_io_u: 0.9000 - val_loss: 0.0242 - val_binary_io_u: 0.7862
# Epoch 38/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0084 - binary_io_u: 0.9018 - val_loss: 0.0201 - val_binary_io_u: 0.7943
# Epoch 39/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0080 - binary_io_u: 0.9059 - val_loss: 0.0182 - val_binary_io_u: 0.8087
# Epoch 40/50
# 38/38 [==============================] - 25s 655ms/step - loss: 0.0079 - binary_io_u: 0.9063 - val_loss: 0.0168 - val_binary_io_u: 0.8269
# Epoch 41/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0072 - binary_io_u: 0.9168 - val_loss: 0.0246 - val_binary_io_u: 0.7584
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0073 - binary_io_u: 0.9153 - val_loss: 0.0201 - val_binary_io_u: 0.7936
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0069 - binary_io_u: 0.9194 - val_loss: 0.0240 - val_binary_io_u: 0.7907
# Epoch 44/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0070 - binary_io_u: 0.9183 - val_loss: 0.0280 - val_binary_io_u: 0.8065
# Epoch 45/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0063 - binary_io_u: 0.9278 - val_loss: 0.0203 - val_binary_io_u: 0.8286
# Epoch 46/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0063 - binary_io_u: 0.9275 - val_loss: 0.0211 - val_binary_io_u: 0.8069
# Epoch 47/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0052 - binary_io_u: 0.9420 - val_loss: 0.0249 - val_binary_io_u: 0.8157
# Epoch 48/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0047 - binary_io_u: 0.9465 - val_loss: 0.0230 - val_binary_io_u: 0.8036
# Epoch 49/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0044 - binary_io_u: 0.9508 - val_loss: 0.0267 - val_binary_io_u: 0.8091
# Epoch 50/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0041 - binary_io_u: 0.9543 - val_loss: 0.0257 - val_binary_io_u: 0.8134

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb2_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.91006577
# Binary IoU = 0.91006577
# Binary IoU for class 1 = 0.8269402
# Binary IoU for class 0 = 0.9931914

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 652ms/step

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
x_test = data["x_test"][kf::2]
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'comb3_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 11:48:14.900764: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:14.905936: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:14.906061: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:14.906921: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:14.907043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:14.907158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:15.334145: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:15.334283: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:15.334390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 11:48:15.334468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 11:48:20.128328: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 11:48:20.186158: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 11:48:24.554449: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x309f8be0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 11:48:24.554464: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 11:48:24.557651: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 11:48:24.601702: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 11:48:24.639848: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 804ms/step - loss: 0.1553 - binary_io_u: 0.5943 - val_loss: 0.3336 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0659 - binary_io_u: 0.7510 - val_loss: 0.2440 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0506 - binary_io_u: 0.7764 - val_loss: 0.2371 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0420 - binary_io_u: 0.7944 - val_loss: 0.2747 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0369 - binary_io_u: 0.8081 - val_loss: 0.3114 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0332 - binary_io_u: 0.8177 - val_loss: 0.2971 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0301 - binary_io_u: 0.8267 - val_loss: 0.3321 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0295 - binary_io_u: 0.8228 - val_loss: 0.3028 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0258 - binary_io_u: 0.8430 - val_loss: 0.3298 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0237 - binary_io_u: 0.8528 - val_loss: 0.3386 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0239 - binary_io_u: 0.8481 - val_loss: 0.3416 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0221 - binary_io_u: 0.8574 - val_loss: 0.3491 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0204 - binary_io_u: 0.8677 - val_loss: 0.3656 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0195 - binary_io_u: 0.8718 - val_loss: 0.3750 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0188 - binary_io_u: 0.8755 - val_loss: 0.3610 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0190 - binary_io_u: 0.8736 - val_loss: 0.0531 - val_binary_io_u: 0.6622
# Epoch 17/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0177 - binary_io_u: 0.8814 - val_loss: 0.0431 - val_binary_io_u: 0.7266
# Epoch 18/50
# 38/38 [==============================] - 25s 650ms/step - loss: 0.0166 - binary_io_u: 0.8887 - val_loss: 0.0346 - val_binary_io_u: 0.8034
# Epoch 19/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0160 - binary_io_u: 0.8919 - val_loss: 0.0335 - val_binary_io_u: 0.7992
# Epoch 20/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0158 - binary_io_u: 0.8929 - val_loss: 0.0544 - val_binary_io_u: 0.7121
# Epoch 21/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0149 - binary_io_u: 0.8986 - val_loss: 0.0651 - val_binary_io_u: 0.7038
# Epoch 22/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0143 - binary_io_u: 0.9020 - val_loss: 0.0450 - val_binary_io_u: 0.7761
# Epoch 23/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0137 - binary_io_u: 0.9068 - val_loss: 0.0465 - val_binary_io_u: 0.7609
# Epoch 24/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0135 - binary_io_u: 0.9082 - val_loss: 0.0429 - val_binary_io_u: 0.7767
# Epoch 25/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0121 - binary_io_u: 0.9182 - val_loss: 0.0586 - val_binary_io_u: 0.7226
# Epoch 26/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0113 - binary_io_u: 0.9231 - val_loss: 0.0523 - val_binary_io_u: 0.7402
# Epoch 27/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0109 - binary_io_u: 0.9260 - val_loss: 0.0528 - val_binary_io_u: 0.7429
# Epoch 28/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0100 - binary_io_u: 0.9325 - val_loss: 0.0664 - val_binary_io_u: 0.7257
# Epoch 29/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0094 - binary_io_u: 0.9371 - val_loss: 0.0772 - val_binary_io_u: 0.7268
# Epoch 30/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0088 - binary_io_u: 0.9410 - val_loss: 0.0666 - val_binary_io_u: 0.7097
# Epoch 31/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0081 - binary_io_u: 0.9463 - val_loss: 0.0572 - val_binary_io_u: 0.7691
# Epoch 32/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0072 - binary_io_u: 0.9523 - val_loss: 0.0467 - val_binary_io_u: 0.8163
# Epoch 33/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0062 - binary_io_u: 0.9596 - val_loss: 0.0496 - val_binary_io_u: 0.8156
# Epoch 34/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0065 - binary_io_u: 0.9573 - val_loss: 0.0606 - val_binary_io_u: 0.7792
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0051 - binary_io_u: 0.9672 - val_loss: 0.0551 - val_binary_io_u: 0.8201
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0047 - binary_io_u: 0.9699 - val_loss: 0.0667 - val_binary_io_u: 0.7813
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0039 - binary_io_u: 0.9751 - val_loss: 0.0503 - val_binary_io_u: 0.8269
# Epoch 38/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0048 - binary_io_u: 0.9683 - val_loss: 0.0685 - val_binary_io_u: 0.7823
# Epoch 39/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0042 - binary_io_u: 0.9732 - val_loss: 0.0659 - val_binary_io_u: 0.8169
# Epoch 40/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0035 - binary_io_u: 0.9776 - val_loss: 0.0603 - val_binary_io_u: 0.8239
# Epoch 41/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0031 - binary_io_u: 0.9809 - val_loss: 0.0558 - val_binary_io_u: 0.8134
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0032 - binary_io_u: 0.9794 - val_loss: 0.0892 - val_binary_io_u: 0.7879
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9828 - val_loss: 0.0653 - val_binary_io_u: 0.8293
# Epoch 44/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0024 - binary_io_u: 0.9849 - val_loss: 0.0669 - val_binary_io_u: 0.8234
# Epoch 45/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0021 - binary_io_u: 0.9875 - val_loss: 0.0682 - val_binary_io_u: 0.8185
# Epoch 46/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0017 - binary_io_u: 0.9903 - val_loss: 0.0694 - val_binary_io_u: 0.8162
# Epoch 47/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0016 - binary_io_u: 0.9907 - val_loss: 0.0723 - val_binary_io_u: 0.8254
# Epoch 48/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0012 - binary_io_u: 0.9936 - val_loss: 0.0779 - val_binary_io_u: 0.8267
# Epoch 49/50
# 38/38 [==============================] - 18s 462ms/step - loss: 9.9104e-04 - binary_io_u: 0.9949 - val_loss: 0.0771 - val_binary_io_u: 0.8251
# Epoch 50/50
# 38/38 [==============================] - 18s 461ms/step - loss: 8.4027e-04 - binary_io_u: 0.9958 - val_loss: 0.0771 - val_binary_io_u: 0.8180

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb3_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.89217496
# Binary IoU = 0.89217496
# Binary IoU for class 1 = 0.799168
# Binary IoU for class 0 = 0.985182

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 655ms/step

# %% [markdown]
# ## prediction images

# %%
data = np.load("../labelmaking/all_scaled_squared_train_label_EDT2_0_30726_res64_s5.npz")

edt = data['train']
#edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('comb2_s_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_comb_scaled_squared_EDT2_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 68ms/step

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_squared_EDT2_res64_concat_s5.npz")
x_train = data["x_train"]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('comb2_s_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 150/150 [==============================] - 10s 67ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)

np.savez_compressed("../Photon_IoU/all_predicted_scaled_squared_comb2_res64", pred=all_predicted)
# Out:
# 38/38 [==============================] - 2s 67ms/step
# (5974, 128, 128, 1)
