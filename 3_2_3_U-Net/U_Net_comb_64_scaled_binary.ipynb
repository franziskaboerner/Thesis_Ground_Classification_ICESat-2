# %% [markdown]
# # EDT+KDE scaled FI and closed labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 20:56:15.621163: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 20:56:16.187375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_binary_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
x_test = data["x_test"][kf::2]
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'comb2_b_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 17:54:26.037424: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.048266: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.048485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.050197: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.050390: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.050554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.473668: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.473801: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.473899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 17:54:26.473978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 17:54:31.353861: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 17:54:31.412235: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 17:54:35.778351: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x308bd650 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 17:54:35.778372: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 17:54:35.781791: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 17:54:35.826295: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 17:54:35.863314: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 799ms/step - loss: 0.2018 - binary_io_u: 0.4620 - val_loss: 0.3136 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0827 - binary_io_u: 0.6335 - val_loss: 0.2309 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 25s 651ms/step - loss: 0.0623 - binary_io_u: 0.6473 - val_loss: 0.1738 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 638ms/step - loss: 0.0509 - binary_io_u: 0.6608 - val_loss: 0.1701 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0447 - binary_io_u: 0.6704 - val_loss: 0.1745 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0425 - binary_io_u: 0.6650 - val_loss: 0.1619 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0375 - binary_io_u: 0.6894 - val_loss: 0.1790 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0345 - binary_io_u: 0.7049 - val_loss: 0.1739 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0312 - binary_io_u: 0.7258 - val_loss: 0.1787 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0299 - binary_io_u: 0.7319 - val_loss: 0.1741 - val_binary_io_u: 0.0056
# Epoch 11/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0270 - binary_io_u: 0.7522 - val_loss: 0.1155 - val_binary_io_u: 4.6744e-06
# Epoch 12/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0261 - binary_io_u: 0.7563 - val_loss: 0.1849 - val_binary_io_u: 1.4023e-05
# Epoch 13/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0242 - binary_io_u: 0.7698 - val_loss: 0.1156 - val_binary_io_u: 0.0907
# Epoch 14/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0228 - binary_io_u: 0.7820 - val_loss: 0.0652 - val_binary_io_u: 0.3726
# Epoch 15/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0230 - binary_io_u: 0.7775 - val_loss: 0.2475 - val_binary_io_u: 0.2512
# Epoch 16/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0224 - binary_io_u: 0.7800 - val_loss: 0.0555 - val_binary_io_u: 0.6051
# Epoch 17/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0210 - binary_io_u: 0.7931 - val_loss: 0.0903 - val_binary_io_u: 0.4133
# Epoch 18/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0202 - binary_io_u: 0.7975 - val_loss: 0.0846 - val_binary_io_u: 0.4300
# Epoch 19/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0198 - binary_io_u: 0.8030 - val_loss: 0.0647 - val_binary_io_u: 0.5719
# Epoch 20/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0189 - binary_io_u: 0.8097 - val_loss: 0.0872 - val_binary_io_u: 0.4990
# Epoch 21/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0179 - binary_io_u: 0.8186 - val_loss: 0.0694 - val_binary_io_u: 0.5295
# Epoch 22/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0181 - binary_io_u: 0.8148 - val_loss: 0.0620 - val_binary_io_u: 0.5861
# Epoch 23/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0179 - binary_io_u: 0.8175 - val_loss: 0.0655 - val_binary_io_u: 0.5631
# Epoch 24/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0181 - binary_io_u: 0.8149 - val_loss: 0.0567 - val_binary_io_u: 0.6211
# Epoch 25/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0176 - binary_io_u: 0.8197 - val_loss: 0.0653 - val_binary_io_u: 0.5892
# Epoch 26/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0171 - binary_io_u: 0.8244 - val_loss: 0.1038 - val_binary_io_u: 0.5450
# Epoch 27/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0170 - binary_io_u: 0.8223 - val_loss: 0.0695 - val_binary_io_u: 0.6000
# Epoch 28/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0157 - binary_io_u: 0.8369 - val_loss: 0.0758 - val_binary_io_u: 0.5876
# Epoch 29/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0159 - binary_io_u: 0.8348 - val_loss: 0.0856 - val_binary_io_u: 0.5468
# Epoch 30/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0148 - binary_io_u: 0.8457 - val_loss: 0.0713 - val_binary_io_u: 0.5070
# Epoch 31/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0147 - binary_io_u: 0.8458 - val_loss: 0.0527 - val_binary_io_u: 0.6332
# Epoch 32/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0140 - binary_io_u: 0.8540 - val_loss: 0.1006 - val_binary_io_u: 0.5541
# Epoch 33/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0138 - binary_io_u: 0.8558 - val_loss: 0.0531 - val_binary_io_u: 0.6335
# Epoch 34/50
# 38/38 [==============================] - 24s 650ms/step - loss: 0.0136 - binary_io_u: 0.8590 - val_loss: 0.0474 - val_binary_io_u: 0.6925
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0130 - binary_io_u: 0.8638 - val_loss: 0.0806 - val_binary_io_u: 0.5613
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0121 - binary_io_u: 0.8744 - val_loss: 0.0556 - val_binary_io_u: 0.6564
# Epoch 37/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0116 - binary_io_u: 0.8792 - val_loss: 0.0487 - val_binary_io_u: 0.6630
# Epoch 38/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0113 - binary_io_u: 0.8821 - val_loss: 0.0593 - val_binary_io_u: 0.6616
# Epoch 39/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0115 - binary_io_u: 0.8797 - val_loss: 0.0657 - val_binary_io_u: 0.6143
# Epoch 40/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0109 - binary_io_u: 0.8868 - val_loss: 0.0526 - val_binary_io_u: 0.6630
# Epoch 41/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0096 - binary_io_u: 0.9001 - val_loss: 0.0637 - val_binary_io_u: 0.6359
# Epoch 42/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.0091 - binary_io_u: 0.9049 - val_loss: 0.0432 - val_binary_io_u: 0.7350
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0089 - binary_io_u: 0.9074 - val_loss: 0.0530 - val_binary_io_u: 0.6941
# Epoch 44/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0086 - binary_io_u: 0.9111 - val_loss: 0.0627 - val_binary_io_u: 0.6445
# Epoch 45/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0080 - binary_io_u: 0.9169 - val_loss: 0.0576 - val_binary_io_u: 0.6520
# Epoch 46/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0069 - binary_io_u: 0.9294 - val_loss: 0.0684 - val_binary_io_u: 0.6233
# Epoch 47/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0059 - binary_io_u: 0.9408 - val_loss: 0.0580 - val_binary_io_u: 0.6674
# Epoch 48/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0058 - binary_io_u: 0.9406 - val_loss: 0.0987 - val_binary_io_u: 0.6091
# Epoch 49/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0051 - binary_io_u: 0.9483 - val_loss: 0.0578 - val_binary_io_u: 0.6957
# Epoch 50/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0042 - binary_io_u: 0.9580 - val_loss: 0.0593 - val_binary_io_u: 0.6969

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb2_b_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.86016196
# Binary IoU = 0.86016196
# Binary IoU for class 1 = 0.73502916
# Binary IoU for class 0 = 0.98529476

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 652ms/step

# %%
plt.imshow(y_test[1])

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
x_test = data["x_test"][kf::2]
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'comb3_b_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-30 16:14:46.248675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.253912: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.254048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.255230: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.255360: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.255475: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.667196: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.667331: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.667429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 16:14:46.667508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-30 16:14:51.431535: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-30 16:14:51.489487: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-30 16:14:55.863567: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f736305a2b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-30 16:14:55.863594: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-30 16:14:55.887418: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-30 16:14:55.996201: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-30 16:14:56.041745: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 800ms/step - loss: 0.1978 - binary_io_u: 0.5051 - val_loss: 0.5014 - val_binary_io_u: 0.0771
# Epoch 2/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0746 - binary_io_u: 0.7555 - val_loss: 0.2943 - val_binary_io_u: 3.3567e-04
# Epoch 3/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0570 - binary_io_u: 0.7707 - val_loss: 0.2465 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0474 - binary_io_u: 0.7812 - val_loss: 0.2547 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0419 - binary_io_u: 0.7879 - val_loss: 0.2635 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0377 - binary_io_u: 0.7968 - val_loss: 0.2844 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0359 - binary_io_u: 0.7987 - val_loss: 0.2948 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0319 - binary_io_u: 0.8148 - val_loss: 0.3853 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0295 - binary_io_u: 0.8244 - val_loss: 0.3387 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0284 - binary_io_u: 0.8275 - val_loss: 0.3278 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0273 - binary_io_u: 0.8308 - val_loss: 0.3182 - val_binary_io_u: 7.5468e-04
# Epoch 12/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0252 - binary_io_u: 0.8425 - val_loss: 0.3466 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0251 - binary_io_u: 0.8394 - val_loss: 0.0522 - val_binary_io_u: 0.6905
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0236 - binary_io_u: 0.8469 - val_loss: 0.1114 - val_binary_io_u: 0.3920
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0232 - binary_io_u: 0.8488 - val_loss: 0.0682 - val_binary_io_u: 0.6289
# Epoch 16/50
# 38/38 [==============================] - 25s 653ms/step - loss: 0.0224 - binary_io_u: 0.8528 - val_loss: 0.0502 - val_binary_io_u: 0.7070
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0221 - binary_io_u: 0.8541 - val_loss: 0.0883 - val_binary_io_u: 0.6015
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0206 - binary_io_u: 0.8627 - val_loss: 0.1156 - val_binary_io_u: 0.5428
# Epoch 19/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0199 - binary_io_u: 0.8665 - val_loss: 0.0763 - val_binary_io_u: 0.6492
# Epoch 20/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0200 - binary_io_u: 0.8656 - val_loss: 0.0993 - val_binary_io_u: 0.5144
# Epoch 21/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0189 - binary_io_u: 0.8725 - val_loss: 0.0963 - val_binary_io_u: 0.6012
# Epoch 22/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0185 - binary_io_u: 0.8744 - val_loss: 0.0979 - val_binary_io_u: 0.5463
# Epoch 23/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0176 - binary_io_u: 0.8815 - val_loss: 0.1041 - val_binary_io_u: 0.6210
# Epoch 24/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0161 - binary_io_u: 0.8908 - val_loss: 0.1100 - val_binary_io_u: 0.6180
# Epoch 25/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0151 - binary_io_u: 0.8973 - val_loss: 0.1091 - val_binary_io_u: 0.6408
# Epoch 26/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0143 - binary_io_u: 0.9026 - val_loss: 0.1565 - val_binary_io_u: 0.5886
# Epoch 27/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0136 - binary_io_u: 0.9083 - val_loss: 0.1330 - val_binary_io_u: 0.6023
# Epoch 28/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0123 - binary_io_u: 0.9169 - val_loss: 0.2191 - val_binary_io_u: 0.5541
# Epoch 29/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0130 - binary_io_u: 0.9113 - val_loss: 0.2046 - val_binary_io_u: 0.4830
# Epoch 30/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0125 - binary_io_u: 0.9159 - val_loss: 0.2167 - val_binary_io_u: 0.5609
# Epoch 31/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0105 - binary_io_u: 0.9291 - val_loss: 0.0896 - val_binary_io_u: 0.6655
# Epoch 32/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0098 - binary_io_u: 0.9341 - val_loss: 0.1586 - val_binary_io_u: 0.6359
# Epoch 33/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0088 - binary_io_u: 0.9410 - val_loss: 0.2009 - val_binary_io_u: 0.6141
# Epoch 34/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0092 - binary_io_u: 0.9376 - val_loss: 0.1536 - val_binary_io_u: 0.6351
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0106 - binary_io_u: 0.9285 - val_loss: 0.1019 - val_binary_io_u: 0.6609
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0075 - binary_io_u: 0.9498 - val_loss: 0.1332 - val_binary_io_u: 0.6697
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0069 - binary_io_u: 0.9537 - val_loss: 0.1151 - val_binary_io_u: 0.6913
# Epoch 38/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0059 - binary_io_u: 0.9610 - val_loss: 0.1378 - val_binary_io_u: 0.6825
# Epoch 39/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0056 - binary_io_u: 0.9626 - val_loss: 0.1186 - val_binary_io_u: 0.7097
# Epoch 40/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0053 - binary_io_u: 0.9649 - val_loss: 0.1202 - val_binary_io_u: 0.7220
# Epoch 41/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0052 - binary_io_u: 0.9660 - val_loss: 0.1140 - val_binary_io_u: 0.7116
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0047 - binary_io_u: 0.9692 - val_loss: 0.1489 - val_binary_io_u: 0.7024
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0043 - binary_io_u: 0.9718 - val_loss: 0.0853 - val_binary_io_u: 0.7648
# Epoch 44/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0038 - binary_io_u: 0.9753 - val_loss: 0.0945 - val_binary_io_u: 0.7750
# Epoch 45/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0034 - binary_io_u: 0.9784 - val_loss: 0.0773 - val_binary_io_u: 0.8037
# Epoch 46/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0035 - binary_io_u: 0.9771 - val_loss: 0.1148 - val_binary_io_u: 0.7500
# Epoch 47/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0032 - binary_io_u: 0.9793 - val_loss: 0.1064 - val_binary_io_u: 0.7684
# Epoch 48/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9825 - val_loss: 0.1034 - val_binary_io_u: 0.7820
# Epoch 49/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0031 - binary_io_u: 0.9801 - val_loss: 0.0962 - val_binary_io_u: 0.7888
# Epoch 50/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9819 - val_loss: 0.1191 - val_binary_io_u: 0.7587

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb3_b_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 1s 67ms/step
# Mean IoU = 0.84256953
# Binary IoU = 0.84257025
# Binary IoU for class 1 = 0.70700586
# Binary IoU for class 0 = 0.97813463

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 676ms/step

# %% [markdown]
# ## prediction images

# %%
data = np.load("../labelmaking/all_scaled_binary_train_label_EDT3_0_30726_res64_s5.npz")

edt = data['train']
#edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('comb3_b_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_comb_scaled_binary_EDT3_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 68ms/step

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('comb3_b_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 150/150 [==============================] - 10s 67ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)
# Out:
# 38/38 [==============================] - 4s 101ms/step
# (5974, 128, 128, 1)

# %%
np.savez_compressed("../Photon_IoU/all_predicted_scaled_binary_comb3_res64", pred=all_predicted)
