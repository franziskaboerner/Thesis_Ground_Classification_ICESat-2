# %% [markdown]
# # EDT+KDE scaled+squared FI and closed labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 20:49:16.758383: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 20:49:17.320793: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][kf::2]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],
)

checkpoint_filepath = 'comb2_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 12:15:47.407051: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.423927: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.424043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.424978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.425091: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.425189: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.839868: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.840002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.840102: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 12:15:47.840181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 12:15:52.844167: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 12:15:52.902405: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 12:15:57.266352: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fc9bc61aa60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 12:15:57.266375: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 12:15:57.269713: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 12:15:57.314124: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 12:15:57.350967: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 801ms/step - loss: 0.1803 - binary_io_u: 0.4705 - val_loss: 0.4255 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0707 - binary_io_u: 0.6457 - val_loss: 0.2474 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.0547 - binary_io_u: 0.6670 - val_loss: 0.2005 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0474 - binary_io_u: 0.6703 - val_loss: 0.1961 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0401 - binary_io_u: 0.7043 - val_loss: 0.2250 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0356 - binary_io_u: 0.7231 - val_loss: 0.2419 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0317 - binary_io_u: 0.7411 - val_loss: 0.2355 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0294 - binary_io_u: 0.7520 - val_loss: 0.2216 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0292 - binary_io_u: 0.7440 - val_loss: 0.2344 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0261 - binary_io_u: 0.7652 - val_loss: 0.2559 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0243 - binary_io_u: 0.7770 - val_loss: 0.2603 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0233 - binary_io_u: 0.7823 - val_loss: 0.2667 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0221 - binary_io_u: 0.7915 - val_loss: 0.2506 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0213 - binary_io_u: 0.7960 - val_loss: 0.2497 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0205 - binary_io_u: 0.8012 - val_loss: 0.0939 - val_binary_io_u: 0.2376
# Epoch 16/50
# 38/38 [==============================] - 25s 656ms/step - loss: 0.0198 - binary_io_u: 0.8070 - val_loss: 0.0571 - val_binary_io_u: 0.4258
# Epoch 17/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0188 - binary_io_u: 0.8135 - val_loss: 0.0378 - val_binary_io_u: 0.6953
# Epoch 18/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0189 - binary_io_u: 0.8121 - val_loss: 0.0427 - val_binary_io_u: 0.6878
# Epoch 19/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0179 - binary_io_u: 0.8215 - val_loss: 0.0338 - val_binary_io_u: 0.7344
# Epoch 20/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0176 - binary_io_u: 0.8233 - val_loss: 0.0311 - val_binary_io_u: 0.7477
# Epoch 21/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0165 - binary_io_u: 0.8339 - val_loss: 0.0351 - val_binary_io_u: 0.7333
# Epoch 22/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0160 - binary_io_u: 0.8371 - val_loss: 0.0395 - val_binary_io_u: 0.7075
# Epoch 23/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0159 - binary_io_u: 0.8379 - val_loss: 0.0338 - val_binary_io_u: 0.7284
# Epoch 24/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0155 - binary_io_u: 0.8413 - val_loss: 0.0583 - val_binary_io_u: 0.6383
# Epoch 25/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0146 - binary_io_u: 0.8504 - val_loss: 0.0812 - val_binary_io_u: 0.5927
# Epoch 26/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0139 - binary_io_u: 0.8566 - val_loss: 0.0507 - val_binary_io_u: 0.6713
# Epoch 27/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0136 - binary_io_u: 0.8603 - val_loss: 0.0674 - val_binary_io_u: 0.6362
# Epoch 28/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0135 - binary_io_u: 0.8617 - val_loss: 0.0507 - val_binary_io_u: 0.6412
# Epoch 29/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0132 - binary_io_u: 0.8631 - val_loss: 0.0461 - val_binary_io_u: 0.6879
# Epoch 30/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0124 - binary_io_u: 0.8731 - val_loss: 0.0758 - val_binary_io_u: 0.5974
# Epoch 31/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0115 - binary_io_u: 0.8820 - val_loss: 0.0713 - val_binary_io_u: 0.5920
# Epoch 32/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0110 - binary_io_u: 0.8872 - val_loss: 0.0519 - val_binary_io_u: 0.6383
# Epoch 33/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0107 - binary_io_u: 0.8896 - val_loss: 0.0617 - val_binary_io_u: 0.6370
# Epoch 34/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0105 - binary_io_u: 0.8915 - val_loss: 0.0665 - val_binary_io_u: 0.6367
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0094 - binary_io_u: 0.9040 - val_loss: 0.0646 - val_binary_io_u: 0.6443
# Epoch 36/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0094 - binary_io_u: 0.9037 - val_loss: 0.0543 - val_binary_io_u: 0.6767
# Epoch 37/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0083 - binary_io_u: 0.9140 - val_loss: 0.0545 - val_binary_io_u: 0.7018
# Epoch 38/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0078 - binary_io_u: 0.9211 - val_loss: 0.0634 - val_binary_io_u: 0.6536
# Epoch 39/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0075 - binary_io_u: 0.9237 - val_loss: 0.0595 - val_binary_io_u: 0.6908
# Epoch 40/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0071 - binary_io_u: 0.9280 - val_loss: 0.0485 - val_binary_io_u: 0.7142
# Epoch 41/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0064 - binary_io_u: 0.9359 - val_loss: 0.0496 - val_binary_io_u: 0.6917
# Epoch 42/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0063 - binary_io_u: 0.9368 - val_loss: 0.0539 - val_binary_io_u: 0.7131
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0056 - binary_io_u: 0.9442 - val_loss: 0.0458 - val_binary_io_u: 0.7187
# Epoch 44/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0055 - binary_io_u: 0.9445 - val_loss: 0.0446 - val_binary_io_u: 0.7478
# Epoch 45/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0049 - binary_io_u: 0.9517 - val_loss: 0.0553 - val_binary_io_u: 0.7157
# Epoch 46/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0046 - binary_io_u: 0.9544 - val_loss: 0.0429 - val_binary_io_u: 0.7671
# Epoch 47/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0044 - binary_io_u: 0.9560 - val_loss: 0.0563 - val_binary_io_u: 0.7344
# Epoch 48/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0038 - binary_io_u: 0.9638 - val_loss: 0.0589 - val_binary_io_u: 0.7259
# Epoch 49/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0032 - binary_io_u: 0.9693 - val_loss: 0.0629 - val_binary_io_u: 0.7074
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0033 - binary_io_u: 0.9679 - val_loss: 0.0512 - val_binary_io_u: 0.7631

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb2_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.8669069
# Binary IoU = 0.8669069
# Binary IoU for class 1 = 0.7477284
# Binary IoU for class 0 = 0.98608536

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 662ms/step

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
x_test = data["x_test"][kf::2]
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'comb3_sb_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 14:09:34.790841: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:34.800071: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:34.800237: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:34.801349: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:34.801491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:34.801615: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:35.224409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:35.224560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:35.224671: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 14:09:35.224761: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 14:09:40.163482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 14:09:40.228739: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 14:09:44.599844: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3003acd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 14:09:44.599861: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 14:09:44.603051: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 14:09:44.646329: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 14:09:44.683094: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 804ms/step - loss: 0.1627 - binary_io_u: 0.5571 - val_loss: 0.3209 - val_binary_io_u: 0.0421
# Epoch 2/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0682 - binary_io_u: 0.7714 - val_loss: 0.2521 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0530 - binary_io_u: 0.7884 - val_loss: 0.2575 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0446 - binary_io_u: 0.8005 - val_loss: 0.2727 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0384 - binary_io_u: 0.8128 - val_loss: 0.2921 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0347 - binary_io_u: 0.8191 - val_loss: 0.3070 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0314 - binary_io_u: 0.8294 - val_loss: 0.3437 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0297 - binary_io_u: 0.8321 - val_loss: 0.3788 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0284 - binary_io_u: 0.8333 - val_loss: 0.3836 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0280 - binary_io_u: 0.8316 - val_loss: 0.3879 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0253 - binary_io_u: 0.8449 - val_loss: 0.3809 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0244 - binary_io_u: 0.8473 - val_loss: 0.3689 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0237 - binary_io_u: 0.8502 - val_loss: 0.3041 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 24s 650ms/step - loss: 0.0225 - binary_io_u: 0.8553 - val_loss: 0.0698 - val_binary_io_u: 0.5721
# Epoch 15/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0227 - binary_io_u: 0.8528 - val_loss: 0.0404 - val_binary_io_u: 0.7823
# Epoch 16/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0212 - binary_io_u: 0.8602 - val_loss: 0.0409 - val_binary_io_u: 0.7731
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0204 - binary_io_u: 0.8649 - val_loss: 0.0424 - val_binary_io_u: 0.7817
# Epoch 18/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0204 - binary_io_u: 0.8645 - val_loss: 0.0782 - val_binary_io_u: 0.6723
# Epoch 19/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0198 - binary_io_u: 0.8673 - val_loss: 0.0749 - val_binary_io_u: 0.7072
# Epoch 20/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0195 - binary_io_u: 0.8701 - val_loss: 0.0729 - val_binary_io_u: 0.7023
# Epoch 21/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0178 - binary_io_u: 0.8800 - val_loss: 0.0688 - val_binary_io_u: 0.6923
# Epoch 22/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0176 - binary_io_u: 0.8809 - val_loss: 0.0971 - val_binary_io_u: 0.6638
# Epoch 23/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0166 - binary_io_u: 0.8883 - val_loss: 0.0503 - val_binary_io_u: 0.7748
# Epoch 24/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0163 - binary_io_u: 0.8891 - val_loss: 0.1021 - val_binary_io_u: 0.6675
# Epoch 25/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0154 - binary_io_u: 0.8965 - val_loss: 0.0531 - val_binary_io_u: 0.7561
# Epoch 26/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0139 - binary_io_u: 0.9062 - val_loss: 0.0857 - val_binary_io_u: 0.6694
# Epoch 27/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0133 - binary_io_u: 0.9098 - val_loss: 0.0613 - val_binary_io_u: 0.7326
# Epoch 28/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0120 - binary_io_u: 0.9189 - val_loss: 0.0872 - val_binary_io_u: 0.7061
# Epoch 29/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0121 - binary_io_u: 0.9188 - val_loss: 0.0479 - val_binary_io_u: 0.7926
# Epoch 30/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0105 - binary_io_u: 0.9300 - val_loss: 0.0490 - val_binary_io_u: 0.8004
# Epoch 31/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0098 - binary_io_u: 0.9345 - val_loss: 0.0693 - val_binary_io_u: 0.7459
# Epoch 32/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0093 - binary_io_u: 0.9380 - val_loss: 0.0559 - val_binary_io_u: 0.7906
# Epoch 33/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0081 - binary_io_u: 0.9464 - val_loss: 0.0523 - val_binary_io_u: 0.7883
# Epoch 34/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0074 - binary_io_u: 0.9510 - val_loss: 0.0521 - val_binary_io_u: 0.8028
# Epoch 35/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0066 - binary_io_u: 0.9566 - val_loss: 0.0693 - val_binary_io_u: 0.7702
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0062 - binary_io_u: 0.9595 - val_loss: 0.0979 - val_binary_io_u: 0.7271
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0059 - binary_io_u: 0.9611 - val_loss: 0.0749 - val_binary_io_u: 0.7845
# Epoch 38/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0053 - binary_io_u: 0.9659 - val_loss: 0.0846 - val_binary_io_u: 0.7805
# Epoch 39/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0044 - binary_io_u: 0.9721 - val_loss: 0.0871 - val_binary_io_u: 0.7742
# Epoch 40/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0040 - binary_io_u: 0.9747 - val_loss: 0.0848 - val_binary_io_u: 0.7763
# Epoch 41/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0033 - binary_io_u: 0.9793 - val_loss: 0.0719 - val_binary_io_u: 0.8008
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9829 - val_loss: 0.0760 - val_binary_io_u: 0.8048
# Epoch 43/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0027 - binary_io_u: 0.9836 - val_loss: 0.0811 - val_binary_io_u: 0.8024
# Epoch 44/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0027 - binary_io_u: 0.9835 - val_loss: 0.0784 - val_binary_io_u: 0.7997
# Epoch 45/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0025 - binary_io_u: 0.9850 - val_loss: 0.0820 - val_binary_io_u: 0.8029
# Epoch 46/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0022 - binary_io_u: 0.9868 - val_loss: 0.0826 - val_binary_io_u: 0.8089
# Epoch 47/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0023 - binary_io_u: 0.9862 - val_loss: 0.0823 - val_binary_io_u: 0.7987
# Epoch 48/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0023 - binary_io_u: 0.9863 - val_loss: 0.0838 - val_binary_io_u: 0.8094
# Epoch 49/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0016 - binary_io_u: 0.9906 - val_loss: 0.0852 - val_binary_io_u: 0.8082
# Epoch 50/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0015 - binary_io_u: 0.9919 - val_loss: 0.0855 - val_binary_io_u: 0.8094

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb3_sb_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.88225996
# Binary IoU = 0.88225996
# Binary IoU for class 1 = 0.7823032
# Binary IoU for class 0 = 0.9822168

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 651ms/step

# %% [markdown]
# ## prediction images

# %%
data = np.load("../labelmaking/all_scaled_squared_binary_train_label_EDT3_0_30726_res64_s5.npz")

edt = data['train']
#edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('comb3_sb_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_comb_scaled_squared_binary_EDT3_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 67ms/step

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_squared_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('comb3_sb_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 2023-10-30 17:10:14.142356: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.148511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.148655: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.149725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.149873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.150002: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.553479: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.553611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.553708: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:10:14.553786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-30 17:10:20.705293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-30 17:10:20.762577: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 150/150 [==============================] - 15s 76ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)
# Out:
# 38/38 [==============================] - 4s 102ms/step
# (5974, 128, 128, 1)

# %%
np.savez_compressed("../Photon_IoU/all_predicted_scaled_squared_binary_comb3_res64", pred=all_predicted)
