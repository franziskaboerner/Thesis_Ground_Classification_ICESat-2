# %% [markdown]
# # EDT+KDE scaled FI and normal labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 20:58:52.706104: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 20:58:53.282726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][kf::2]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],   
)

checkpoint_filepath = 'comb2_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 10:36:15.688819: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:15.694276: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:15.694415: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:15.695393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:15.695532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:15.695649: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:16.115541: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:16.115682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:16.115782: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:36:16.115862: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 10:36:21.060305: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 10:36:21.119065: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:36:25.506974: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8e76e46ea0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 10:36:25.506998: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 10:36:25.510161: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 10:36:25.553780: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:36:25.590888: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 803ms/step - loss: 0.1893 - binary_io_u: 0.4425 - val_loss: 0.3400 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 24s 638ms/step - loss: 0.0779 - binary_io_u: 0.5575 - val_loss: 0.1968 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0577 - binary_io_u: 0.5780 - val_loss: 0.2046 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0488 - binary_io_u: 0.5923 - val_loss: 0.1700 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0429 - binary_io_u: 0.6126 - val_loss: 0.1794 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0376 - binary_io_u: 0.6546 - val_loss: 0.1578 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0318 - binary_io_u: 0.7063 - val_loss: 0.1590 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0306 - binary_io_u: 0.6985 - val_loss: 0.1592 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 25s 651ms/step - loss: 0.0243 - binary_io_u: 0.7646 - val_loss: 0.1520 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0216 - binary_io_u: 0.7878 - val_loss: 0.1708 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0201 - binary_io_u: 0.7973 - val_loss: 0.1669 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0183 - binary_io_u: 0.8134 - val_loss: 0.1756 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0166 - binary_io_u: 0.8292 - val_loss: 0.1983 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0159 - binary_io_u: 0.8328 - val_loss: 0.2002 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0146 - binary_io_u: 0.8446 - val_loss: 0.0442 - val_binary_io_u: 0.4730
# Epoch 16/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0133 - binary_io_u: 0.8581 - val_loss: 0.0289 - val_binary_io_u: 0.6822
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0133 - binary_io_u: 0.8555 - val_loss: 0.0289 - val_binary_io_u: 0.6979
# Epoch 18/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0125 - binary_io_u: 0.8617 - val_loss: 0.0380 - val_binary_io_u: 0.6192
# Epoch 19/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0122 - binary_io_u: 0.8653 - val_loss: 0.0430 - val_binary_io_u: 0.5882
# Epoch 20/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0116 - binary_io_u: 0.8697 - val_loss: 0.0424 - val_binary_io_u: 0.6002
# Epoch 21/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0110 - binary_io_u: 0.8757 - val_loss: 0.0331 - val_binary_io_u: 0.6455
# Epoch 22/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0107 - binary_io_u: 0.8787 - val_loss: 0.0516 - val_binary_io_u: 0.5422
# Epoch 23/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0102 - binary_io_u: 0.8837 - val_loss: 0.0364 - val_binary_io_u: 0.6148
# Epoch 24/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0102 - binary_io_u: 0.8829 - val_loss: 0.0300 - val_binary_io_u: 0.6909
# Epoch 25/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0097 - binary_io_u: 0.8885 - val_loss: 0.0493 - val_binary_io_u: 0.5833
# Epoch 26/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0094 - binary_io_u: 0.8904 - val_loss: 0.0468 - val_binary_io_u: 0.5712
# Epoch 27/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0088 - binary_io_u: 0.8994 - val_loss: 0.0563 - val_binary_io_u: 0.5549
# Epoch 28/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0090 - binary_io_u: 0.8949 - val_loss: 0.0672 - val_binary_io_u: 0.5396
# Epoch 29/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0085 - binary_io_u: 0.9009 - val_loss: 0.0637 - val_binary_io_u: 0.5437
# Epoch 30/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0078 - binary_io_u: 0.9097 - val_loss: 0.0471 - val_binary_io_u: 0.5905
# Epoch 31/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0077 - binary_io_u: 0.9112 - val_loss: 0.0491 - val_binary_io_u: 0.5957
# Epoch 32/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0074 - binary_io_u: 0.9140 - val_loss: 0.0242 - val_binary_io_u: 0.7913
# Epoch 33/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0068 - binary_io_u: 0.9219 - val_loss: 0.0356 - val_binary_io_u: 0.7074
# Epoch 34/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0073 - binary_io_u: 0.9165 - val_loss: 0.0470 - val_binary_io_u: 0.5846
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0061 - binary_io_u: 0.9301 - val_loss: 0.0574 - val_binary_io_u: 0.5349
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0059 - binary_io_u: 0.9319 - val_loss: 0.0544 - val_binary_io_u: 0.5790
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0055 - binary_io_u: 0.9380 - val_loss: 0.0473 - val_binary_io_u: 0.6234
# Epoch 38/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0050 - binary_io_u: 0.9438 - val_loss: 0.0498 - val_binary_io_u: 0.6055
# Epoch 39/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0044 - binary_io_u: 0.9508 - val_loss: 0.0240 - val_binary_io_u: 0.8074
# Epoch 40/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0044 - binary_io_u: 0.9507 - val_loss: 0.0287 - val_binary_io_u: 0.7628
# Epoch 41/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0039 - binary_io_u: 0.9567 - val_loss: 0.0353 - val_binary_io_u: 0.7518
# Epoch 42/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0036 - binary_io_u: 0.9601 - val_loss: 0.0431 - val_binary_io_u: 0.6963
# Epoch 43/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0031 - binary_io_u: 0.9657 - val_loss: 0.0298 - val_binary_io_u: 0.8146
# Epoch 44/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0027 - binary_io_u: 0.9713 - val_loss: 0.0428 - val_binary_io_u: 0.7438
# Epoch 45/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9697 - val_loss: 0.0503 - val_binary_io_u: 0.6547
# Epoch 46/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0025 - binary_io_u: 0.9733 - val_loss: 0.0302 - val_binary_io_u: 0.8160
# Epoch 47/50
# 18/38 [=============>................] - ETA: 8s - loss: 0.0022 - binary_io_u: 0.9772

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb2_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 64ms/step
# Mean IoU = 0.8997438
# Binary IoU = 0.8997438
# Binary IoU for class 1 = 0.80739135
# Binary IoU for class 0 = 0.9920962

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 672ms/step

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][kf::2]
x_test = data["x_test"][kf::2]
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'comb3_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 2)
# (597, 128, 128, 2)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 10:54:32.783400: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:32.787763: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:32.787875: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:32.788771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:32.788883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:32.788980: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:33.206496: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:33.206652: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:33.206770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:54:33.206870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-06 10:54:38.185686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 10:54:38.244775: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:54:42.647828: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3188fb10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 10:54:42.647849: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 10:54:42.651044: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 10:54:42.695033: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:54:42.732049: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 809ms/step - loss: 0.1542 - binary_io_u: 0.6063 - val_loss: 0.3545 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 25s 657ms/step - loss: 0.0660 - binary_io_u: 0.7335 - val_loss: 0.2462 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0520 - binary_io_u: 0.7534 - val_loss: 0.2391 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0449 - binary_io_u: 0.7661 - val_loss: 0.2441 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0383 - binary_io_u: 0.7894 - val_loss: 0.2636 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0344 - binary_io_u: 0.8021 - val_loss: 0.2835 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0322 - binary_io_u: 0.8100 - val_loss: 0.2899 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0286 - binary_io_u: 0.8255 - val_loss: 0.3085 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0270 - binary_io_u: 0.8325 - val_loss: 0.3294 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0260 - binary_io_u: 0.8352 - val_loss: 0.3345 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0251 - binary_io_u: 0.8377 - val_loss: 0.3741 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0245 - binary_io_u: 0.8419 - val_loss: 0.4119 - val_binary_io_u: 0.0012
# Epoch 13/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0225 - binary_io_u: 0.8525 - val_loss: 0.3439 - val_binary_io_u: 6.3322e-05
# Epoch 14/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0221 - binary_io_u: 0.8537 - val_loss: 0.1640 - val_binary_io_u: 0.1873
# Epoch 15/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0210 - binary_io_u: 0.8607 - val_loss: 0.0863 - val_binary_io_u: 0.4267
# Epoch 16/50
# 38/38 [==============================] - 25s 650ms/step - loss: 0.0197 - binary_io_u: 0.8675 - val_loss: 0.0432 - val_binary_io_u: 0.7601
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0188 - binary_io_u: 0.8745 - val_loss: 0.0702 - val_binary_io_u: 0.6565
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0185 - binary_io_u: 0.8741 - val_loss: 0.0518 - val_binary_io_u: 0.7068
# Epoch 19/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0174 - binary_io_u: 0.8818 - val_loss: 0.0853 - val_binary_io_u: 0.6456
# Epoch 20/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0168 - binary_io_u: 0.8857 - val_loss: 0.0690 - val_binary_io_u: 0.7115
# Epoch 21/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0159 - binary_io_u: 0.8916 - val_loss: 0.1396 - val_binary_io_u: 0.5589
# Epoch 22/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0157 - binary_io_u: 0.8921 - val_loss: 0.0756 - val_binary_io_u: 0.6672
# Epoch 23/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0142 - binary_io_u: 0.9019 - val_loss: 0.1205 - val_binary_io_u: 0.6160
# Epoch 24/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0135 - binary_io_u: 0.9072 - val_loss: 0.0842 - val_binary_io_u: 0.6533
# Epoch 25/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0122 - binary_io_u: 0.9165 - val_loss: 0.1070 - val_binary_io_u: 0.6262
# Epoch 26/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0140 - binary_io_u: 0.9050 - val_loss: 0.1102 - val_binary_io_u: 0.6520
# Epoch 27/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0109 - binary_io_u: 0.9264 - val_loss: 0.1297 - val_binary_io_u: 0.6303
# Epoch 28/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0107 - binary_io_u: 0.9278 - val_loss: 0.0944 - val_binary_io_u: 0.6512
# Epoch 29/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0094 - binary_io_u: 0.9364 - val_loss: 0.0848 - val_binary_io_u: 0.6741
# Epoch 30/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0088 - binary_io_u: 0.9405 - val_loss: 0.0777 - val_binary_io_u: 0.6796
# Epoch 31/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0077 - binary_io_u: 0.9485 - val_loss: 0.1258 - val_binary_io_u: 0.6312
# Epoch 32/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0068 - binary_io_u: 0.9553 - val_loss: 0.0723 - val_binary_io_u: 0.7089
# Epoch 33/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0066 - binary_io_u: 0.9562 - val_loss: 0.1130 - val_binary_io_u: 0.6454
# Epoch 34/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0060 - binary_io_u: 0.9604 - val_loss: 0.0809 - val_binary_io_u: 0.6915
# Epoch 35/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0059 - binary_io_u: 0.9606 - val_loss: 0.0989 - val_binary_io_u: 0.6745
# Epoch 36/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0055 - binary_io_u: 0.9643 - val_loss: 0.1015 - val_binary_io_u: 0.6813
# Epoch 37/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0047 - binary_io_u: 0.9698 - val_loss: 0.0765 - val_binary_io_u: 0.7500
# Epoch 38/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0044 - binary_io_u: 0.9716 - val_loss: 0.0770 - val_binary_io_u: 0.7590
# Epoch 39/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0037 - binary_io_u: 0.9759 - val_loss: 0.0970 - val_binary_io_u: 0.6979
# Epoch 40/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0034 - binary_io_u: 0.9782 - val_loss: 0.1053 - val_binary_io_u: 0.7119
# Epoch 41/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0026 - binary_io_u: 0.9841 - val_loss: 0.0914 - val_binary_io_u: 0.7675
# Epoch 42/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0024 - binary_io_u: 0.9851 - val_loss: 0.0792 - val_binary_io_u: 0.7468
# Epoch 43/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0027 - binary_io_u: 0.9832 - val_loss: 0.0753 - val_binary_io_u: 0.8115
# Epoch 44/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0020 - binary_io_u: 0.9879 - val_loss: 0.0957 - val_binary_io_u: 0.7668
# Epoch 45/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0018 - binary_io_u: 0.9892 - val_loss: 0.0950 - val_binary_io_u: 0.7851
# Epoch 46/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0023 - binary_io_u: 0.9854 - val_loss: 0.0864 - val_binary_io_u: 0.7782
# Epoch 47/50
# 38/38 [==============================] - 18s 464ms/step - loss: 0.0017 - binary_io_u: 0.9899 - val_loss: 0.0749 - val_binary_io_u: 0.8212
# Epoch 48/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0013 - binary_io_u: 0.9929 - val_loss: 0.0744 - val_binary_io_u: 0.8257
# Epoch 49/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0012 - binary_io_u: 0.9930 - val_loss: 0.0775 - val_binary_io_u: 0.8244
# Epoch 50/50
# 38/38 [==============================] - 18s 463ms/step - loss: 0.0013 - binary_io_u: 0.9924 - val_loss: 0.0818 - val_binary_io_u: 0.8204

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('comb3_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 64ms/step
# Mean IoU = 0.87019795
# Binary IoU = 0.87019795
# Binary IoU for class 1 = 0.76009125
# Binary IoU for class 0 = 0.98030466

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 662ms/step

# %% [markdown]
# ## prediction images

# %%
data = np.load("../labelmaking/all_scaled_train_label_EDT2_0_30726_res64_s5.npz")

edt = data['train']
#edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('comb2_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_comb_scaled_EDT2_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 68ms/step

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_EDT3_res64_concat_s5.npz")
x_train = data["x_train"]
#x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"]
#x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('comb3_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 2023-10-30 17:03:30.631616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:30.638019: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:30.638162: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:30.639465: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:30.639618: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:30.639748: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:31.044431: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:31.044563: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:31.044659: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-30 17:03:31.044738: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-30 17:03:37.021223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-30 17:03:37.079411: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 150/150 [==============================] - 14s 76ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)

np.savez_compressed("../Photon_IoU/all_predicted_scaled_comb3_res64", pred=all_predicted)
# Out:
# 38/38 [==============================] - 4s 101ms/step
# (5974, 128, 128, 1)
