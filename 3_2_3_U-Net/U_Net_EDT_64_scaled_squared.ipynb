# %% [markdown]
# # EDT only, scaled+squared FI and normal labels

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-11-07 17:10:07.433205: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 17:10:07.999837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],
)

checkpoint_filepath = 'edt2_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 15:21:13.045211: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.052972: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.053142: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.054320: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.054497: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.054647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.475805: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.475943: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.476042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:21:13.476126: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 15:21:18.155910: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 15:21:18.214102: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 15:21:22.561241: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fdd34541090 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 15:21:22.561261: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 15:21:22.564624: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 15:21:22.609259: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 15:21:22.646963: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 797ms/step - loss: 0.2321 - binary_io_u: 0.3054 - val_loss: 0.8202 - val_binary_io_u: 0.0364
# Epoch 2/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0734 - binary_io_u: 0.6586 - val_loss: 0.3299 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0516 - binary_io_u: 0.7101 - val_loss: 0.2089 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0382 - binary_io_u: 0.7753 - val_loss: 0.1533 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0299 - binary_io_u: 0.8176 - val_loss: 0.1484 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0249 - binary_io_u: 0.8357 - val_loss: 0.1491 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0227 - binary_io_u: 0.8355 - val_loss: 0.1609 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0197 - binary_io_u: 0.8485 - val_loss: 0.1579 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0174 - binary_io_u: 0.8590 - val_loss: 0.1636 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0159 - binary_io_u: 0.8658 - val_loss: 0.1704 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0149 - binary_io_u: 0.8677 - val_loss: 0.1754 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0138 - binary_io_u: 0.8745 - val_loss: 0.1774 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0132 - binary_io_u: 0.8754 - val_loss: 0.1886 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0124 - binary_io_u: 0.8805 - val_loss: 0.1905 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0117 - binary_io_u: 0.8848 - val_loss: 0.1956 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0110 - binary_io_u: 0.8902 - val_loss: 0.2079 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0108 - binary_io_u: 0.8901 - val_loss: 0.2036 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0104 - binary_io_u: 0.8914 - val_loss: 0.2119 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0100 - binary_io_u: 0.8953 - val_loss: 0.2104 - val_binary_io_u: 0.0000e+00
# Epoch 20/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0090 - binary_io_u: 0.9049 - val_loss: 0.2056 - val_binary_io_u: 0.0000e+00
# Epoch 21/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0089 - binary_io_u: 0.9065 - val_loss: 0.1949 - val_binary_io_u: 3.4525e-04
# Epoch 22/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0088 - binary_io_u: 0.9054 - val_loss: 0.0459 - val_binary_io_u: 0.4563
# Epoch 23/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0086 - binary_io_u: 0.9079 - val_loss: 0.1379 - val_binary_io_u: 0.0375
# Epoch 24/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0084 - binary_io_u: 0.9087 - val_loss: 0.2304 - val_binary_io_u: 0.0000e+00
# Epoch 25/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.0075 - binary_io_u: 0.9185 - val_loss: 0.0313 - val_binary_io_u: 0.6284
# Epoch 26/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0069 - binary_io_u: 0.9262 - val_loss: 0.1819 - val_binary_io_u: 0.0118
# Epoch 27/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0069 - binary_io_u: 0.9240 - val_loss: 0.1280 - val_binary_io_u: 0.0764
# Epoch 28/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0064 - binary_io_u: 0.9308 - val_loss: 0.0634 - val_binary_io_u: 0.3781
# Epoch 29/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0060 - binary_io_u: 0.9352 - val_loss: 0.0333 - val_binary_io_u: 0.7289
# Epoch 30/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0058 - binary_io_u: 0.9368 - val_loss: 0.0396 - val_binary_io_u: 0.5537
# Epoch 31/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0053 - binary_io_u: 0.9438 - val_loss: 0.1146 - val_binary_io_u: 0.1764
# Epoch 32/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0053 - binary_io_u: 0.9434 - val_loss: 0.1751 - val_binary_io_u: 0.0319
# Epoch 33/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0054 - binary_io_u: 0.9413 - val_loss: 0.3178 - val_binary_io_u: 0.3017
# Epoch 34/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0058 - binary_io_u: 0.9359 - val_loss: 0.0409 - val_binary_io_u: 0.7315
# Epoch 35/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0045 - binary_io_u: 0.9523 - val_loss: 0.0601 - val_binary_io_u: 0.4361
# Epoch 36/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0043 - binary_io_u: 0.9539 - val_loss: 0.0924 - val_binary_io_u: 0.2598
# Epoch 37/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0036 - binary_io_u: 0.9616 - val_loss: 0.0798 - val_binary_io_u: 0.3555
# Epoch 38/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.0033 - binary_io_u: 0.9661 - val_loss: 0.0256 - val_binary_io_u: 0.7893
# Epoch 39/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0029 - binary_io_u: 0.9704 - val_loss: 0.0249 - val_binary_io_u: 0.8174
# Epoch 40/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0027 - binary_io_u: 0.9729 - val_loss: 0.1261 - val_binary_io_u: 0.1930
# Epoch 41/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0023 - binary_io_u: 0.9775 - val_loss: 0.0392 - val_binary_io_u: 0.6683
# Epoch 42/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0021 - binary_io_u: 0.9791 - val_loss: 0.0307 - val_binary_io_u: 0.7956
# Epoch 43/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0019 - binary_io_u: 0.9813 - val_loss: 0.0324 - val_binary_io_u: 0.8126
# Epoch 44/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0016 - binary_io_u: 0.9854 - val_loss: 0.0346 - val_binary_io_u: 0.8178
# Epoch 45/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0015 - binary_io_u: 0.9863 - val_loss: 0.0336 - val_binary_io_u: 0.7848
# Epoch 46/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0012 - binary_io_u: 0.9893 - val_loss: 0.0351 - val_binary_io_u: 0.7708
# Epoch 47/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0013 - binary_io_u: 0.9884 - val_loss: 0.0326 - val_binary_io_u: 0.7969
# Epoch 48/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0010 - binary_io_u: 0.9917 - val_loss: 0.0362 - val_binary_io_u: 0.7790
# Epoch 49/50
# 38/38 [==============================] - 17s 461ms/step - loss: 8.9071e-04 - binary_io_u: 0.9929 - val_loss: 0.0373 - val_binary_io_u: 0.7945
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 7.4270e-04 - binary_io_u: 0.9946 - val_loss: 0.0472 - val_binary_io_u: 0.7025

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt2_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 62ms/step
# Mean IoU = 0.90508807
# Binary IoU = 0.90508807
# Binary IoU for class 1 = 0.81735164
# Binary IoU for class 0 = 0.9928245

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 653ms/step

# %%
model.save(
    "unet-global-px%i-bs%i-lr%0.3f-ep%i_%i-kde-edt-combined.keras"
    % (input_shape[0], batch_size, learning_rate, epochs, x_train.shape[0])
)

pd.DataFrame.from_dict(history.history).to_csv('history_edt_comb.csv',index=False)

# %% [markdown]
# ### other half of the dataset

# %%
kf = 1

data = np.load("../labelmaking/all_scaled_squared_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
xx = np.concatenate((x_train, x_test))
print(xx.shape)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)
yy = np.concatenate((y_train, y_test))
print(yy.shape)
# Out:
# (2987, 128, 128, 1)
# (2987, 128, 128, 1)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt2_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(xx)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=yy)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=yy)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=yy)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=yy)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 94/94 [==============================] - 6s 67ms/step
# Mean IoU = 0.94412446
# Binary IoU = 0.94412446
# Binary IoU for class 1 = 0.89821005
# Binary IoU for class 0 = 0.99003893

# %% [markdown]
# ## EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'edt3_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 15:52:17.844814: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:17.850329: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:17.850466: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:17.851566: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:17.851692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:17.851804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:18.271456: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:18.271592: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:18.271688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 15:52:18.271767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 15:52:22.940791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 15:52:22.999188: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 15:52:27.369287: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fedac0636e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 15:52:27.369305: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 15:52:27.372632: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 15:52:27.415600: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 15:52:27.453608: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 802ms/step - loss: 0.1256 - binary_io_u: 0.6310 - val_loss: 0.8762 - val_binary_io_u: 0.0026
# Epoch 2/50
# 38/38 [==============================] - 24s 633ms/step - loss: 0.0486 - binary_io_u: 0.7785 - val_loss: 0.2445 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0385 - binary_io_u: 0.8003 - val_loss: 0.2286 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0330 - binary_io_u: 0.8188 - val_loss: 0.2508 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0302 - binary_io_u: 0.8263 - val_loss: 0.2849 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0286 - binary_io_u: 0.8306 - val_loss: 0.3158 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0256 - binary_io_u: 0.8450 - val_loss: 0.3409 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0238 - binary_io_u: 0.8529 - val_loss: 0.3657 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0216 - binary_io_u: 0.8650 - val_loss: 0.3637 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0211 - binary_io_u: 0.8650 - val_loss: 0.3907 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0205 - binary_io_u: 0.8682 - val_loss: 0.3733 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0186 - binary_io_u: 0.8800 - val_loss: 0.3847 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0182 - binary_io_u: 0.8811 - val_loss: 0.3821 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0172 - binary_io_u: 0.8868 - val_loss: 0.3721 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0163 - binary_io_u: 0.8913 - val_loss: 0.3634 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0155 - binary_io_u: 0.8974 - val_loss: 0.3801 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0146 - binary_io_u: 0.9028 - val_loss: 0.3769 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0138 - binary_io_u: 0.9078 - val_loss: 0.3994 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0139 - binary_io_u: 0.9065 - val_loss: 0.4629 - val_binary_io_u: 0.0000e+00
# Epoch 20/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0131 - binary_io_u: 0.9125 - val_loss: 0.1604 - val_binary_io_u: 0.2891
# Epoch 21/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0117 - binary_io_u: 0.9221 - val_loss: 0.3788 - val_binary_io_u: 0.0043
# Epoch 22/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0106 - binary_io_u: 0.9293 - val_loss: 0.3867 - val_binary_io_u: 0.0064
# Epoch 23/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.0103 - binary_io_u: 0.9309 - val_loss: 0.1377 - val_binary_io_u: 0.3627
# Epoch 24/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0096 - binary_io_u: 0.9358 - val_loss: 0.1435 - val_binary_io_u: 0.4235
# Epoch 25/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0119 - binary_io_u: 0.9211 - val_loss: 0.3096 - val_binary_io_u: 0.4158
# Epoch 26/50
# 38/38 [==============================] - 24s 642ms/step - loss: 0.0099 - binary_io_u: 0.9352 - val_loss: 0.0392 - val_binary_io_u: 0.8209
# Epoch 27/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0082 - binary_io_u: 0.9459 - val_loss: 0.4049 - val_binary_io_u: 0.0218
# Epoch 28/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0065 - binary_io_u: 0.9579 - val_loss: 0.0924 - val_binary_io_u: 0.5831
# Epoch 29/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0060 - binary_io_u: 0.9616 - val_loss: 0.0661 - val_binary_io_u: 0.6980
# Epoch 30/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0057 - binary_io_u: 0.9637 - val_loss: 0.2916 - val_binary_io_u: 0.1377
# Epoch 31/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0054 - binary_io_u: 0.9653 - val_loss: 0.0528 - val_binary_io_u: 0.8065
# Epoch 32/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0048 - binary_io_u: 0.9696 - val_loss: 0.2313 - val_binary_io_u: 0.2724
# Epoch 33/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0043 - binary_io_u: 0.9727 - val_loss: 0.2578 - val_binary_io_u: 0.2261
# Epoch 34/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0037 - binary_io_u: 0.9769 - val_loss: 0.0880 - val_binary_io_u: 0.6682
# Epoch 35/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0038 - binary_io_u: 0.9757 - val_loss: 0.0900 - val_binary_io_u: 0.6777
# Epoch 36/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0034 - binary_io_u: 0.9790 - val_loss: 0.1199 - val_binary_io_u: 0.5752
# Epoch 37/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0028 - binary_io_u: 0.9834 - val_loss: 0.0789 - val_binary_io_u: 0.7615
# Epoch 38/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0030 - binary_io_u: 0.9814 - val_loss: 0.0912 - val_binary_io_u: 0.6772
# Epoch 39/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0023 - binary_io_u: 0.9861 - val_loss: 0.1027 - val_binary_io_u: 0.6616
# Epoch 40/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0021 - binary_io_u: 0.9882 - val_loss: 0.1170 - val_binary_io_u: 0.6190
# Epoch 41/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0019 - binary_io_u: 0.9886 - val_loss: 0.0652 - val_binary_io_u: 0.8245
# Epoch 42/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0015 - binary_io_u: 0.9915 - val_loss: 0.0752 - val_binary_io_u: 0.7841
# Epoch 43/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0019 - binary_io_u: 0.9886 - val_loss: 0.0692 - val_binary_io_u: 0.8258
# Epoch 44/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0017 - binary_io_u: 0.9902 - val_loss: 0.0798 - val_binary_io_u: 0.7976
# Epoch 45/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0015 - binary_io_u: 0.9911 - val_loss: 0.0785 - val_binary_io_u: 0.8011
# Epoch 46/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0020 - binary_io_u: 0.9884 - val_loss: 0.0748 - val_binary_io_u: 0.8008
# Epoch 47/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0021 - binary_io_u: 0.9876 - val_loss: 0.0813 - val_binary_io_u: 0.7565
# Epoch 48/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0016 - binary_io_u: 0.9905 - val_loss: 0.0892 - val_binary_io_u: 0.7930
# Epoch 49/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0011 - binary_io_u: 0.9941 - val_loss: 0.0750 - val_binary_io_u: 0.8305
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 8.1673e-04 - binary_io_u: 0.9958 - val_loss: 0.0729 - val_binary_io_u: 0.8122

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt3_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.903723
# Binary IoU = 0.903723
# Binary IoU for class 1 = 0.8209333
# Binary IoU for class 0 = 0.9865128

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 666ms/step

# %% [markdown]
# ## EDT4

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT4_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'edt4_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 16:10:35.183128: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.187770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.187886: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.188850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.188961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.189057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.668672: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.668838: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.668955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:10:35.669053: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 16:10:40.270695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 16:10:40.329026: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 16:10:44.738600: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff2e40035a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 16:10:44.738619: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 16:10:44.741958: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 16:10:44.786532: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 16:10:44.823400: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 810ms/step - loss: 0.1774 - binary_io_u: 0.5827 - val_loss: 23.6696 - val_binary_io_u: 0.0838
# Epoch 2/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0663 - binary_io_u: 0.8028 - val_loss: 0.3295 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 25s 662ms/step - loss: 0.0532 - binary_io_u: 0.8146 - val_loss: 0.3012 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0461 - binary_io_u: 0.8234 - val_loss: 0.3110 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0394 - binary_io_u: 0.8399 - val_loss: 0.3366 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0349 - binary_io_u: 0.8535 - val_loss: 0.3744 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0320 - binary_io_u: 0.8606 - val_loss: 0.4204 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0302 - binary_io_u: 0.8639 - val_loss: 0.4394 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0283 - binary_io_u: 0.8700 - val_loss: 0.4756 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0268 - binary_io_u: 0.8744 - val_loss: 0.4938 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0268 - binary_io_u: 0.8719 - val_loss: 0.5108 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0250 - binary_io_u: 0.8788 - val_loss: 0.5530 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0234 - binary_io_u: 0.8850 - val_loss: 0.5342 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0225 - binary_io_u: 0.8886 - val_loss: 0.5457 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0216 - binary_io_u: 0.8923 - val_loss: 0.5680 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0201 - binary_io_u: 0.8992 - val_loss: 0.6011 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0200 - binary_io_u: 0.8989 - val_loss: 0.5739 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0197 - binary_io_u: 0.9002 - val_loss: 0.6057 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0186 - binary_io_u: 0.9047 - val_loss: 0.6687 - val_binary_io_u: 0.0000e+00
# Epoch 20/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0183 - binary_io_u: 0.9064 - val_loss: 0.6148 - val_binary_io_u: 0.0000e+00
# Epoch 21/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0171 - binary_io_u: 0.9121 - val_loss: 0.4317 - val_binary_io_u: 0.0012
# Epoch 22/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0164 - binary_io_u: 0.9151 - val_loss: 0.1180 - val_binary_io_u: 0.4671
# Epoch 23/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0150 - binary_io_u: 0.9233 - val_loss: 0.5826 - val_binary_io_u: 4.8849e-06
# Epoch 24/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0146 - binary_io_u: 0.9250 - val_loss: 0.0400 - val_binary_io_u: 0.8259
# Epoch 25/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0137 - binary_io_u: 0.9295 - val_loss: 0.0935 - val_binary_io_u: 0.6878
# Epoch 26/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0131 - binary_io_u: 0.9333 - val_loss: 0.2617 - val_binary_io_u: 0.2095
# Epoch 27/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0125 - binary_io_u: 0.9354 - val_loss: 0.0414 - val_binary_io_u: 0.8251
# Epoch 28/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0113 - binary_io_u: 0.9420 - val_loss: 0.5806 - val_binary_io_u: 0.0024
# Epoch 29/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0108 - binary_io_u: 0.9448 - val_loss: 0.0775 - val_binary_io_u: 0.7394
# Epoch 30/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0097 - binary_io_u: 0.9507 - val_loss: 0.2465 - val_binary_io_u: 0.3448
# Epoch 31/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0092 - binary_io_u: 0.9539 - val_loss: 0.0466 - val_binary_io_u: 0.8234
# Epoch 32/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0086 - binary_io_u: 0.9566 - val_loss: 0.0467 - val_binary_io_u: 0.8433
# Epoch 33/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0080 - binary_io_u: 0.9600 - val_loss: 0.0438 - val_binary_io_u: 0.8385
# Epoch 34/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0082 - binary_io_u: 0.9589 - val_loss: 0.1005 - val_binary_io_u: 0.7291
# Epoch 35/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0069 - binary_io_u: 0.9657 - val_loss: 0.0536 - val_binary_io_u: 0.8287
# Epoch 36/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0061 - binary_io_u: 0.9699 - val_loss: 0.1297 - val_binary_io_u: 0.6358
# Epoch 37/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0059 - binary_io_u: 0.9714 - val_loss: 0.0595 - val_binary_io_u: 0.8306
# Epoch 38/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0054 - binary_io_u: 0.9737 - val_loss: 0.0626 - val_binary_io_u: 0.8199
# Epoch 39/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0049 - binary_io_u: 0.9762 - val_loss: 0.0528 - val_binary_io_u: 0.8387
# Epoch 40/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0055 - binary_io_u: 0.9731 - val_loss: 0.0922 - val_binary_io_u: 0.7349
# Epoch 41/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0050 - binary_io_u: 0.9758 - val_loss: 0.1372 - val_binary_io_u: 0.6555
# Epoch 42/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0050 - binary_io_u: 0.9755 - val_loss: 0.0735 - val_binary_io_u: 0.7902
# Epoch 43/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0046 - binary_io_u: 0.9775 - val_loss: 0.0648 - val_binary_io_u: 0.8338
# Epoch 44/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0037 - binary_io_u: 0.9822 - val_loss: 0.0702 - val_binary_io_u: 0.8303
# Epoch 45/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0031 - binary_io_u: 0.9853 - val_loss: 0.0705 - val_binary_io_u: 0.8414
# Epoch 46/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0026 - binary_io_u: 0.9879 - val_loss: 0.0713 - val_binary_io_u: 0.8302
# Epoch 47/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0028 - binary_io_u: 0.9871 - val_loss: 0.0736 - val_binary_io_u: 0.8283
# Epoch 48/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0025 - binary_io_u: 0.9883 - val_loss: 0.0786 - val_binary_io_u: 0.8187
# Epoch 49/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0025 - binary_io_u: 0.9886 - val_loss: 0.0789 - val_binary_io_u: 0.8348
# Epoch 50/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0029 - binary_io_u: 0.9863 - val_loss: 0.0850 - val_binary_io_u: 0.7753

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt4_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 62ms/step
# Mean IoU = 0.9042711
# Binary IoU = 0.9042711
# Binary IoU for class 1 = 0.8259256
# Binary IoU for class 0 = 0.9826166

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 664ms/step

# %% [markdown]
# ## EDT5

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_squared_EDT5_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'edt5_s_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 16:32:25.289432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.294850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.294983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.296065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.296195: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.296310: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.773630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.773769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.773870: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 16:32:25.773967: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 16:32:30.467535: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 16:32:30.525864: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 16:32:34.894629: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f402c611ed0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 16:32:34.894651: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 16:32:34.898031: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 16:32:34.942302: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 16:32:34.978979: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 800ms/step - loss: 0.1640 - binary_io_u: 0.6519 - val_loss: 1.1011 - val_binary_io_u: 0.0969
# Epoch 2/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0637 - binary_io_u: 0.8354 - val_loss: 0.3304 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 25s 659ms/step - loss: 0.0520 - binary_io_u: 0.8462 - val_loss: 0.3280 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0453 - binary_io_u: 0.8547 - val_loss: 0.3763 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0399 - binary_io_u: 0.8656 - val_loss: 0.4179 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0364 - binary_io_u: 0.8724 - val_loss: 0.4528 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0334 - binary_io_u: 0.8789 - val_loss: 0.4845 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0312 - binary_io_u: 0.8836 - val_loss: 0.5133 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0293 - binary_io_u: 0.8881 - val_loss: 0.5550 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0282 - binary_io_u: 0.8913 - val_loss: 0.5780 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0270 - binary_io_u: 0.8929 - val_loss: 0.5738 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0250 - binary_io_u: 0.8998 - val_loss: 0.5875 - val_binary_io_u: 0.0000e+00
# Epoch 13/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0247 - binary_io_u: 0.8987 - val_loss: 0.6293 - val_binary_io_u: 0.0000e+00
# Epoch 14/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0236 - binary_io_u: 0.9037 - val_loss: 0.6268 - val_binary_io_u: 0.0000e+00
# Epoch 15/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0231 - binary_io_u: 0.9039 - val_loss: 0.6989 - val_binary_io_u: 0.0000e+00
# Epoch 16/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0216 - binary_io_u: 0.9095 - val_loss: 0.6567 - val_binary_io_u: 0.0000e+00
# Epoch 17/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0199 - binary_io_u: 0.9166 - val_loss: 0.7347 - val_binary_io_u: 0.0000e+00
# Epoch 18/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0192 - binary_io_u: 0.9193 - val_loss: 0.7799 - val_binary_io_u: 0.0000e+00
# Epoch 19/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0181 - binary_io_u: 0.9236 - val_loss: 0.5352 - val_binary_io_u: 0.0062
# Epoch 20/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0173 - binary_io_u: 0.9268 - val_loss: 0.6787 - val_binary_io_u: 5.8332e-05
# Epoch 21/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0162 - binary_io_u: 0.9313 - val_loss: 0.7451 - val_binary_io_u: 2.0115e-06
# Epoch 22/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0153 - binary_io_u: 0.9354 - val_loss: 0.2048 - val_binary_io_u: 0.3932
# Epoch 23/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0151 - binary_io_u: 0.9362 - val_loss: 0.7420 - val_binary_io_u: 3.9928e-04
# Epoch 24/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0139 - binary_io_u: 0.9416 - val_loss: 0.2328 - val_binary_io_u: 0.4007
# Epoch 25/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0126 - binary_io_u: 0.9468 - val_loss: 0.3883 - val_binary_io_u: 0.1807
# Epoch 26/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0118 - binary_io_u: 0.9506 - val_loss: 0.1714 - val_binary_io_u: 0.5176
# Epoch 27/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0118 - binary_io_u: 0.9503 - val_loss: 0.1549 - val_binary_io_u: 0.6127
# Epoch 28/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0109 - binary_io_u: 0.9551 - val_loss: 0.0677 - val_binary_io_u: 0.8065
# Epoch 29/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0119 - binary_io_u: 0.9511 - val_loss: 0.5375 - val_binary_io_u: 0.0780
# Epoch 30/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0104 - binary_io_u: 0.9566 - val_loss: 0.1301 - val_binary_io_u: 0.6374
# Epoch 31/50
# 38/38 [==============================] - 25s 657ms/step - loss: 0.0088 - binary_io_u: 0.9636 - val_loss: 0.0658 - val_binary_io_u: 0.8381
# Epoch 32/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0079 - binary_io_u: 0.9676 - val_loss: 0.0795 - val_binary_io_u: 0.7920
# Epoch 33/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0076 - binary_io_u: 0.9689 - val_loss: 0.0620 - val_binary_io_u: 0.8559
# Epoch 34/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0067 - binary_io_u: 0.9725 - val_loss: 0.0665 - val_binary_io_u: 0.8343
# Epoch 35/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0071 - binary_io_u: 0.9710 - val_loss: 0.1217 - val_binary_io_u: 0.7178
# Epoch 36/50
# 38/38 [==============================] - 24s 649ms/step - loss: 0.0065 - binary_io_u: 0.9734 - val_loss: 0.0601 - val_binary_io_u: 0.8549
# Epoch 37/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0061 - binary_io_u: 0.9756 - val_loss: 0.0956 - val_binary_io_u: 0.8062
# Epoch 38/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0060 - binary_io_u: 0.9757 - val_loss: 0.0809 - val_binary_io_u: 0.8249
# Epoch 39/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0055 - binary_io_u: 0.9775 - val_loss: 0.0714 - val_binary_io_u: 0.8621
# Epoch 40/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0045 - binary_io_u: 0.9821 - val_loss: 0.0620 - val_binary_io_u: 0.8655
# Epoch 41/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0042 - binary_io_u: 0.9835 - val_loss: 0.0774 - val_binary_io_u: 0.8485
# Epoch 42/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0040 - binary_io_u: 0.9843 - val_loss: 0.0776 - val_binary_io_u: 0.8558
# Epoch 43/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0042 - binary_io_u: 0.9832 - val_loss: 0.0796 - val_binary_io_u: 0.8634
# Epoch 44/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0032 - binary_io_u: 0.9877 - val_loss: 0.0810 - val_binary_io_u: 0.8488
# Epoch 45/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0032 - binary_io_u: 0.9878 - val_loss: 0.0719 - val_binary_io_u: 0.8608
# Epoch 46/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0038 - binary_io_u: 0.9851 - val_loss: 0.0919 - val_binary_io_u: 0.8497
# Epoch 47/50
# 38/38 [==============================] - 18s 462ms/step - loss: 0.0034 - binary_io_u: 0.9864 - val_loss: 0.0688 - val_binary_io_u: 0.8554
# Epoch 48/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0036 - binary_io_u: 0.9855 - val_loss: 0.0879 - val_binary_io_u: 0.8367
# Epoch 49/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0032 - binary_io_u: 0.9876 - val_loss: 0.0940 - val_binary_io_u: 0.8456
# Epoch 50/50
# 38/38 [==============================] - 18s 461ms/step - loss: 0.0028 - binary_io_u: 0.9892 - val_loss: 0.0886 - val_binary_io_u: 0.8598

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt5_s_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.91851014
# Binary IoU = 0.91851014
# Binary IoU for class 1 = 0.85488445
# Binary IoU for class 0 = 0.98213583

# %%
k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 659ms/step

# %% [markdown]
# ## prediction images

# %%
data = np.load("../labelmaking/all_scaled_squared_train_label_EDT2_0_30726_res64_s5.npz")

edt = data['train'][:,:,:,0]
edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('edt2_s_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_scaled_squared_EDT2_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 67ms/step

# %%
# load data and best model
data = np.load("../labelmaking/all_scaled_squared_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('edt2_s_64_00008_1')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5
# Out:
# 150/150 [==============================] - 12s 76ms/step

# %%
# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)
# Out:
# 38/38 [==============================] - 4s 101ms/step
# (5974, 128, 128, 1)

# %%
np.savez_compressed("../Photon_IoU/all_predicted_scaled_squared_00008_1_EDT2_res64", pred=all_predicted)
