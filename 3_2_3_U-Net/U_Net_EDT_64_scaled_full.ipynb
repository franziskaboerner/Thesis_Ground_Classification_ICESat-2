# %% [markdown]
# # EDT only, scaled FI and normal labels on the full dataset

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized EDT feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-10 12:06:30.742263: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-10 12:06:31.326390: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## EDT2

# %%
data = np.load("../labelmaking/all_scaled_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,0]#[kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,0]#[kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]#[kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]#[kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'edt2_64_f'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (4780, 128, 128, 1)
# (1194, 128, 128, 1)
# (4780, 128, 128, 1)
# (1194, 128, 128, 1)
# 2023-10-10 12:06:53.072873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.078294: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.078437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.079354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.079483: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.079598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.496458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.496596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.496696: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-10 12:06:53.496775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-10 12:06:58.572178: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-10 12:06:58.630637: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-10 12:07:02.997963: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f36e83835c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-10 12:07:02.997985: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-10 12:07:03.001404: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-10 12:07:03.046441: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-10 12:07:03.083686: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 75/75 [==============================] - 74s 703ms/step - loss: 0.1560 - binary_io_u: 0.2728 - val_loss: 0.2542 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 75/75 [==============================] - 41s 550ms/step - loss: 0.0547 - binary_io_u: 0.6354 - val_loss: 0.1675 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 75/75 [==============================] - 42s 556ms/step - loss: 0.0341 - binary_io_u: 0.7548 - val_loss: 0.1441 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 75/75 [==============================] - 35s 462ms/step - loss: 0.0248 - binary_io_u: 0.8040 - val_loss: 0.1468 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 75/75 [==============================] - 42s 559ms/step - loss: 0.0196 - binary_io_u: 0.8329 - val_loss: 0.1412 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 75/75 [==============================] - 35s 463ms/step - loss: 0.0170 - binary_io_u: 0.8446 - val_loss: 0.1516 - val_binary_io_u: 0.0000e+00
# Epoch 7/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0148 - binary_io_u: 0.8571 - val_loss: 0.1854 - val_binary_io_u: 0.0000e+00
# Epoch 8/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0133 - binary_io_u: 0.8653 - val_loss: 0.2064 - val_binary_io_u: 0.0000e+00
# Epoch 9/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0125 - binary_io_u: 0.8676 - val_loss: 0.1992 - val_binary_io_u: 0.0000e+00
# Epoch 10/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0116 - binary_io_u: 0.8742 - val_loss: 0.2050 - val_binary_io_u: 0.0000e+00
# Epoch 11/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0107 - binary_io_u: 0.8814 - val_loss: 0.2086 - val_binary_io_u: 0.0000e+00
# Epoch 12/50
# 75/75 [==============================] - 42s 558ms/step - loss: 0.0102 - binary_io_u: 0.8855 - val_loss: 0.0776 - val_binary_io_u: 0.3521
# Epoch 13/50
# 75/75 [==============================] - 35s 464ms/step - loss: 0.0095 - binary_io_u: 0.8914 - val_loss: 0.1969 - val_binary_io_u: 8.3871e-04
# Epoch 14/50
# 75/75 [==============================] - 42s 558ms/step - loss: 0.0089 - binary_io_u: 0.8981 - val_loss: 0.0560 - val_binary_io_u: 0.4620
# Epoch 15/50
# 75/75 [==============================] - 35s 464ms/step - loss: 0.0082 - binary_io_u: 0.9053 - val_loss: 0.2268 - val_binary_io_u: 0.0016
# Epoch 16/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0076 - binary_io_u: 0.9124 - val_loss: 0.0773 - val_binary_io_u: 0.3502
# Epoch 17/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0070 - binary_io_u: 0.9191 - val_loss: 0.0975 - val_binary_io_u: 0.2113
# Epoch 18/50
# 75/75 [==============================] - 42s 561ms/step - loss: 0.0063 - binary_io_u: 0.9278 - val_loss: 0.0307 - val_binary_io_u: 0.6518
# Epoch 19/50
# 75/75 [==============================] - 35s 464ms/step - loss: 0.0058 - binary_io_u: 0.9342 - val_loss: 0.1652 - val_binary_io_u: 0.1427
# Epoch 20/50
# 75/75 [==============================] - 42s 559ms/step - loss: 0.0049 - binary_io_u: 0.9445 - val_loss: 0.0228 - val_binary_io_u: 0.7776
# Epoch 21/50
# 75/75 [==============================] - 35s 464ms/step - loss: 0.0041 - binary_io_u: 0.9544 - val_loss: 0.1087 - val_binary_io_u: 0.2769
# Epoch 22/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0037 - binary_io_u: 0.9593 - val_loss: 0.1649 - val_binary_io_u: 0.1391
# Epoch 23/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0029 - binary_io_u: 0.9697 - val_loss: 0.1344 - val_binary_io_u: 0.2278
# Epoch 24/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0022 - binary_io_u: 0.9774 - val_loss: 0.0445 - val_binary_io_u: 0.6512
# Epoch 25/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0021 - binary_io_u: 0.9789 - val_loss: 0.0466 - val_binary_io_u: 0.6676
# Epoch 26/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0020 - binary_io_u: 0.9799 - val_loss: 0.1171 - val_binary_io_u: 0.3124
# Epoch 27/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0013 - binary_io_u: 0.9877 - val_loss: 0.0610 - val_binary_io_u: 0.5621
# Epoch 28/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0010 - binary_io_u: 0.9910 - val_loss: 0.0384 - val_binary_io_u: 0.7943
# Epoch 29/50
# 75/75 [==============================] - 35s 466ms/step - loss: 7.8153e-04 - binary_io_u: 0.9935 - val_loss: 0.0446 - val_binary_io_u: 0.8169
# Epoch 30/50
# 75/75 [==============================] - 35s 466ms/step - loss: 6.7877e-04 - binary_io_u: 0.9945 - val_loss: 0.0494 - val_binary_io_u: 0.6655
# Epoch 31/50
# 75/75 [==============================] - 35s 466ms/step - loss: 8.2519e-04 - binary_io_u: 0.9925 - val_loss: 0.0408 - val_binary_io_u: 0.7448
# Epoch 32/50
# 75/75 [==============================] - 35s 466ms/step - loss: 6.6030e-04 - binary_io_u: 0.9943 - val_loss: 0.0585 - val_binary_io_u: 0.8125
# Epoch 33/50
# 75/75 [==============================] - 35s 466ms/step - loss: 4.5631e-04 - binary_io_u: 0.9966 - val_loss: 0.0564 - val_binary_io_u: 0.8085
# Epoch 34/50
# 75/75 [==============================] - 35s 466ms/step - loss: 5.9746e-04 - binary_io_u: 0.9951 - val_loss: 0.0421 - val_binary_io_u: 0.7860
# Epoch 35/50
# 75/75 [==============================] - 35s 466ms/step - loss: 5.6356e-04 - binary_io_u: 0.9950 - val_loss: 0.0440 - val_binary_io_u: 0.7823
# Epoch 36/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0270 - binary_io_u: 0.6810 - val_loss: 11.7160 - val_binary_io_u: 0.0292
# Epoch 37/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0183 - binary_io_u: 0.7932 - val_loss: 1.1116 - val_binary_io_u: 0.1427
# Epoch 38/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0116 - binary_io_u: 0.8646 - val_loss: 0.1566 - val_binary_io_u: 0.4055
# Epoch 39/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0095 - binary_io_u: 0.8858 - val_loss: 0.0631 - val_binary_io_u: 0.1335
# Epoch 40/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0088 - binary_io_u: 0.8947 - val_loss: 0.2353 - val_binary_io_u: 0.0013
# Epoch 41/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0071 - binary_io_u: 0.9155 - val_loss: 0.2061 - val_binary_io_u: 0.0291
# Epoch 42/50
# 75/75 [==============================] - 42s 556ms/step - loss: 0.0064 - binary_io_u: 0.9234 - val_loss: 0.0218 - val_binary_io_u: 0.7690
# Epoch 43/50
# 75/75 [==============================] - 35s 464ms/step - loss: 0.0055 - binary_io_u: 0.9347 - val_loss: 0.0657 - val_binary_io_u: 0.4042
# Epoch 44/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0045 - binary_io_u: 0.9478 - val_loss: 0.3054 - val_binary_io_u: 0.0092
# Epoch 45/50
# 75/75 [==============================] - 35s 465ms/step - loss: 0.0037 - binary_io_u: 0.9576 - val_loss: 0.0271 - val_binary_io_u: 0.7384
# Epoch 46/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0031 - binary_io_u: 0.9652 - val_loss: 0.0305 - val_binary_io_u: 0.8191
# Epoch 47/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0026 - binary_io_u: 0.9701 - val_loss: 0.1558 - val_binary_io_u: 0.2076
# Epoch 48/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0021 - binary_io_u: 0.9760 - val_loss: 0.0280 - val_binary_io_u: 0.8046
# Epoch 49/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0017 - binary_io_u: 0.9806 - val_loss: 0.1179 - val_binary_io_u: 0.5597
# Epoch 50/50
# 75/75 [==============================] - 35s 466ms/step - loss: 0.0018 - binary_io_u: 0.9803 - val_loss: 0.0828 - val_binary_io_u: 0.4663

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('edt2_64_f')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 38/38 [==============================] - 6s 99ms/step
# Mean IoU = 0.8793642
# Binary IoU = 0.8793642
# Binary IoU for class 1 = 0.76898986
# Binary IoU for class 0 = 0.9897385

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 660ms/step
