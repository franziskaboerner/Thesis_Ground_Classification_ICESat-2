# %% [markdown]
# # KDE

# %% [markdown]
# ### note: the colorbar labels on the prediction images are incorrect and should read 'normalized KDE feature input' instead of 'EDT [m]'

# %% [markdown]
# ## modules

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
import time
# Out:
# 2023-10-31 21:00:35.652025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 21:00:36.224444: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## loss plot function

# %%
def learning_progress(history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(loss) + 1)
    ground_iou = history.history["binary_io_u"]
    val_ground_iou = history.history["val_binary_io_u"]
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    fig.set_dpi(200)
    ax[0].semilogy(epochs, loss, "b", label="Training loss")
    ax[0].plot(epochs, val_loss, "r", label="Validation loss")
    ax[0].set_title("Training and validation loss")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Loss")
    ax[0].grid()
    ax[0].legend()
    ax[1].plot(epochs, ground_iou, "b", label="Training IoU")
    ax[1].plot(epochs, val_ground_iou, "r", label="Validation IoU")
    ax[1].set_title("Training and validation IoU")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("IoU")
    ax[1].grid()
    ax[1].legend()
    plt.show()

# %% [markdown]
# ## KDE 64 (all the same)

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,1][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,1][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,1][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,1][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],
)

checkpoint_filepath = 'kde_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-05 21:50:25.745554: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:25.751082: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:25.751212: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:25.752156: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:25.752284: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:25.752396: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:26.169220: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:26.169351: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:26.169445: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 21:50:26.169523: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-05 21:50:30.716818: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-05 21:50:30.776513: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 21:50:35.122442: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f8ee0a1b230 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 21:50:35.122461: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-05 21:50:35.125624: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 21:50:35.169027: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 21:50:35.206152: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 796ms/step - loss: 0.1368 - binary_io_u: 0.7826 - val_loss: 0.4342 - val_binary_io_u: 0.0000e+00
# Epoch 2/50
# 38/38 [==============================] - 17s 452ms/step - loss: 0.0698 - binary_io_u: 0.8545 - val_loss: 0.5410 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 17s 454ms/step - loss: 0.0622 - binary_io_u: 0.8607 - val_loss: 0.6385 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0578 - binary_io_u: 0.8648 - val_loss: 0.5017 - val_binary_io_u: 0.1041
# Epoch 5/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0566 - binary_io_u: 0.8661 - val_loss: 0.3509 - val_binary_io_u: 0.3176
# Epoch 6/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0537 - binary_io_u: 0.8709 - val_loss: 0.1924 - val_binary_io_u: 0.6025
# Epoch 7/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0514 - binary_io_u: 0.8746 - val_loss: 0.5475 - val_binary_io_u: 7.1134e-04
# Epoch 8/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0491 - binary_io_u: 0.8790 - val_loss: 0.1653 - val_binary_io_u: 0.6992
# Epoch 9/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0486 - binary_io_u: 0.8795 - val_loss: 0.1346 - val_binary_io_u: 0.7391
# Epoch 10/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0462 - binary_io_u: 0.8848 - val_loss: 0.1430 - val_binary_io_u: 0.7382
# Epoch 11/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0450 - binary_io_u: 0.8874 - val_loss: 1.2971 - val_binary_io_u: 0.2690
# Epoch 12/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0448 - binary_io_u: 0.8880 - val_loss: 0.1216 - val_binary_io_u: 0.7690
# Epoch 13/50
# 38/38 [==============================] - 24s 647ms/step - loss: 0.0425 - binary_io_u: 0.8932 - val_loss: 0.1178 - val_binary_io_u: 0.7367
# Epoch 14/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0419 - binary_io_u: 0.8944 - val_loss: 0.0926 - val_binary_io_u: 0.8028
# Epoch 15/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0406 - binary_io_u: 0.8974 - val_loss: 0.1054 - val_binary_io_u: 0.7927
# Epoch 16/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0400 - binary_io_u: 0.8991 - val_loss: 0.0863 - val_binary_io_u: 0.8199
# Epoch 17/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0394 - binary_io_u: 0.9006 - val_loss: 0.0921 - val_binary_io_u: 0.8123
# Epoch 18/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0383 - binary_io_u: 0.9030 - val_loss: 0.0985 - val_binary_io_u: 0.8040
# Epoch 19/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0379 - binary_io_u: 0.9040 - val_loss: 0.1229 - val_binary_io_u: 0.8065
# Epoch 20/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0369 - binary_io_u: 0.9062 - val_loss: 0.1281 - val_binary_io_u: 0.7967
# Epoch 21/50
# 38/38 [==============================] - 25s 651ms/step - loss: 0.0366 - binary_io_u: 0.9069 - val_loss: 0.0760 - val_binary_io_u: 0.8446
# Epoch 22/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0364 - binary_io_u: 0.9074 - val_loss: 0.0970 - val_binary_io_u: 0.8078
# Epoch 23/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0356 - binary_io_u: 0.9097 - val_loss: 0.1153 - val_binary_io_u: 0.8041
# Epoch 24/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0350 - binary_io_u: 0.9105 - val_loss: 0.1615 - val_binary_io_u: 0.7876
# Epoch 25/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0357 - binary_io_u: 0.9089 - val_loss: 0.1417 - val_binary_io_u: 0.7888
# Epoch 26/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0345 - binary_io_u: 0.9120 - val_loss: 0.1007 - val_binary_io_u: 0.8246
# Epoch 27/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0341 - binary_io_u: 0.9127 - val_loss: 0.1231 - val_binary_io_u: 0.8048
# Epoch 28/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0349 - binary_io_u: 0.9104 - val_loss: 0.0770 - val_binary_io_u: 0.8571
# Epoch 29/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0330 - binary_io_u: 0.9155 - val_loss: 0.0828 - val_binary_io_u: 0.8425
# Epoch 30/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0321 - binary_io_u: 0.9178 - val_loss: 0.0871 - val_binary_io_u: 0.8355
# Epoch 31/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0322 - binary_io_u: 0.9174 - val_loss: 0.4396 - val_binary_io_u: 0.4868
# Epoch 32/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0308 - binary_io_u: 0.9209 - val_loss: 0.6166 - val_binary_io_u: 0.3919
# Epoch 33/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0313 - binary_io_u: 0.9200 - val_loss: 0.2637 - val_binary_io_u: 0.6812
# Epoch 34/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0305 - binary_io_u: 0.9218 - val_loss: 0.2929 - val_binary_io_u: 0.5884
# Epoch 35/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0306 - binary_io_u: 0.9219 - val_loss: 0.1514 - val_binary_io_u: 0.8073
# Epoch 36/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0290 - binary_io_u: 0.9254 - val_loss: 0.0628 - val_binary_io_u: 0.8674
# Epoch 37/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0285 - binary_io_u: 0.9262 - val_loss: 0.1059 - val_binary_io_u: 0.8145
# Epoch 38/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0285 - binary_io_u: 0.9265 - val_loss: 0.1125 - val_binary_io_u: 0.8176
# Epoch 39/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0288 - binary_io_u: 0.9261 - val_loss: 0.1315 - val_binary_io_u: 0.8065
# Epoch 40/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0282 - binary_io_u: 0.9274 - val_loss: 0.1025 - val_binary_io_u: 0.8259
# Epoch 41/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0272 - binary_io_u: 0.9296 - val_loss: 0.0879 - val_binary_io_u: 0.8435
# Epoch 42/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0257 - binary_io_u: 0.9332 - val_loss: 0.0915 - val_binary_io_u: 0.8466
# Epoch 43/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0265 - binary_io_u: 0.9313 - val_loss: 0.0990 - val_binary_io_u: 0.8447
# Epoch 44/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0257 - binary_io_u: 0.9336 - val_loss: 0.0917 - val_binary_io_u: 0.8416
# Epoch 45/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0264 - binary_io_u: 0.9317 - val_loss: 0.1125 - val_binary_io_u: 0.8167
# Epoch 46/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0248 - binary_io_u: 0.9361 - val_loss: 0.2125 - val_binary_io_u: 0.7452
# Epoch 47/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0239 - binary_io_u: 0.9383 - val_loss: 0.3049 - val_binary_io_u: 0.6944
# Epoch 48/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0231 - binary_io_u: 0.9400 - val_loss: 0.3534 - val_binary_io_u: 0.5712
# Epoch 49/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0241 - binary_io_u: 0.9374 - val_loss: 0.4845 - val_binary_io_u: 0.4948
# Epoch 50/50
# 38/38 [==============================] - 17s 461ms/step - loss: 0.0221 - binary_io_u: 0.9428 - val_loss: 0.4803 - val_binary_io_u: 0.4904

# %%
learning_progress(history)

# %%
kf = 0
data = np.load("../labelmaking/all_scaled_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,1][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,1][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,1][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,1][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('kde_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.91996586
# Binary IoU = 0.91996586
# Binary IoU for class 1 = 0.8674239
# Binary IoU for class 0 = 0.9725078

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 1
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
ax.imshow(y_test[k] > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 0s 16ms/step

# %% [markdown]
# ## with binary edt label

# %% [markdown]
# #### EDT2

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_binary_EDT2_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,1][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,1][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],  
)

checkpoint_filepath = 'kde_edtlabel2_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-09 18:14:07.744878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:07.750397: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:07.750528: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:07.751444: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:07.751579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:07.751695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:08.175045: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:08.175183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:08.175282: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-09 18:14:08.175362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/50
# 2023-10-09 18:14:12.965451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-09 18:14:13.025365: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-09 18:14:17.397949: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f81d4131720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-09 18:14:17.397967: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-09 18:14:17.426452: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-09 18:14:17.540719: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-09 18:14:17.589305: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 52s 798ms/step - loss: 0.2213 - binary_io_u: 0.3956 - val_loss: 0.4555 - val_binary_io_u: 0.0061
# Epoch 2/50
# 38/38 [==============================] - 24s 629ms/step - loss: 0.0796 - binary_io_u: 0.6331 - val_loss: 0.1940 - val_binary_io_u: 0.0000e+00
# Epoch 3/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0607 - binary_io_u: 0.6464 - val_loss: 0.1476 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0516 - binary_io_u: 0.6499 - val_loss: 0.1326 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0466 - binary_io_u: 0.6513 - val_loss: 0.1142 - val_binary_io_u: 0.0000e+00
# Epoch 6/50
# 38/38 [==============================] - 24s 638ms/step - loss: 0.0431 - binary_io_u: 0.6525 - val_loss: 0.0934 - val_binary_io_u: 0.0442
# Epoch 7/50
# 38/38 [==============================] - 17s 453ms/step - loss: 0.0409 - binary_io_u: 0.6549 - val_loss: 0.0955 - val_binary_io_u: 0.1343
# Epoch 8/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0390 - binary_io_u: 0.6573 - val_loss: 0.0688 - val_binary_io_u: 0.3764
# Epoch 9/50
# 38/38 [==============================] - 17s 454ms/step - loss: 0.0382 - binary_io_u: 0.6566 - val_loss: 0.0731 - val_binary_io_u: 0.4053
# Epoch 10/50
# 38/38 [==============================] - 24s 646ms/step - loss: 0.0372 - binary_io_u: 0.6589 - val_loss: 0.0620 - val_binary_io_u: 0.5211
# Epoch 11/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0363 - binary_io_u: 0.6606 - val_loss: 0.0636 - val_binary_io_u: 0.4129
# Epoch 12/50
# 38/38 [==============================] - 24s 643ms/step - loss: 0.0352 - binary_io_u: 0.6647 - val_loss: 0.0536 - val_binary_io_u: 0.5411
# Epoch 13/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0348 - binary_io_u: 0.6653 - val_loss: 0.0532 - val_binary_io_u: 0.5672
# Epoch 14/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0345 - binary_io_u: 0.6658 - val_loss: 0.0527 - val_binary_io_u: 0.6039
# Epoch 15/50
# 38/38 [==============================] - 17s 454ms/step - loss: 0.0339 - binary_io_u: 0.6694 - val_loss: 0.0543 - val_binary_io_u: 0.5744
# Epoch 16/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0333 - binary_io_u: 0.6731 - val_loss: 0.0491 - val_binary_io_u: 0.5822
# Epoch 17/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0333 - binary_io_u: 0.6709 - val_loss: 0.0506 - val_binary_io_u: 0.5430
# Epoch 18/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0325 - binary_io_u: 0.6759 - val_loss: 0.0477 - val_binary_io_u: 0.5926
# Epoch 19/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0322 - binary_io_u: 0.6793 - val_loss: 0.0457 - val_binary_io_u: 0.6202
# Epoch 20/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0318 - binary_io_u: 0.6801 - val_loss: 0.0492 - val_binary_io_u: 0.5742
# Epoch 21/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0316 - binary_io_u: 0.6831 - val_loss: 0.0499 - val_binary_io_u: 0.5787
# Epoch 22/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0318 - binary_io_u: 0.6793 - val_loss: 0.0519 - val_binary_io_u: 0.6032
# Epoch 23/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0314 - binary_io_u: 0.6839 - val_loss: 0.0522 - val_binary_io_u: 0.5348
# Epoch 24/50
# 38/38 [==============================] - 24s 648ms/step - loss: 0.0310 - binary_io_u: 0.6872 - val_loss: 0.0452 - val_binary_io_u: 0.6322
# Epoch 25/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0305 - binary_io_u: 0.6920 - val_loss: 0.0640 - val_binary_io_u: 0.4902
# Epoch 26/50
# 38/38 [==============================] - 24s 639ms/step - loss: 0.0305 - binary_io_u: 0.6906 - val_loss: 0.0446 - val_binary_io_u: 0.6297
# Epoch 27/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0301 - binary_io_u: 0.6949 - val_loss: 0.0522 - val_binary_io_u: 0.5483
# Epoch 28/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0297 - binary_io_u: 0.6989 - val_loss: 0.0471 - val_binary_io_u: 0.5903
# Epoch 29/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0307 - binary_io_u: 0.6942 - val_loss: 0.0470 - val_binary_io_u: 0.6004
# Epoch 30/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0300 - binary_io_u: 0.6975 - val_loss: 0.0470 - val_binary_io_u: 0.5976
# Epoch 31/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0292 - binary_io_u: 0.7039 - val_loss: 0.0513 - val_binary_io_u: 0.5514
# Epoch 32/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0285 - binary_io_u: 0.7089 - val_loss: 0.0481 - val_binary_io_u: 0.5971
# Epoch 33/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0282 - binary_io_u: 0.7115 - val_loss: 0.0469 - val_binary_io_u: 0.6051
# Epoch 34/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0280 - binary_io_u: 0.7134 - val_loss: 0.0475 - val_binary_io_u: 0.6007
# Epoch 35/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0276 - binary_io_u: 0.7161 - val_loss: 0.0466 - val_binary_io_u: 0.6200
# Epoch 36/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0273 - binary_io_u: 0.7193 - val_loss: 0.0489 - val_binary_io_u: 0.6149
# Epoch 37/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0269 - binary_io_u: 0.7247 - val_loss: 0.0501 - val_binary_io_u: 0.5897
# Epoch 38/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0263 - binary_io_u: 0.7290 - val_loss: 0.0473 - val_binary_io_u: 0.6145
# Epoch 39/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0260 - binary_io_u: 0.7319 - val_loss: 0.0541 - val_binary_io_u: 0.5592
# Epoch 40/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0255 - binary_io_u: 0.7357 - val_loss: 0.0500 - val_binary_io_u: 0.5961
# Epoch 41/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0252 - binary_io_u: 0.7381 - val_loss: 0.0507 - val_binary_io_u: 0.6114
# Epoch 42/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0246 - binary_io_u: 0.7441 - val_loss: 0.0515 - val_binary_io_u: 0.6159
# Epoch 43/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0249 - binary_io_u: 0.7423 - val_loss: 0.0562 - val_binary_io_u: 0.5682
# Epoch 44/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0239 - binary_io_u: 0.7517 - val_loss: 0.0552 - val_binary_io_u: 0.5667
# Epoch 45/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0232 - binary_io_u: 0.7575 - val_loss: 0.0511 - val_binary_io_u: 0.5991
# Epoch 46/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0228 - binary_io_u: 0.7621 - val_loss: 0.0516 - val_binary_io_u: 0.6092
# Epoch 47/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0221 - binary_io_u: 0.7686 - val_loss: 0.0546 - val_binary_io_u: 0.6028
# Epoch 48/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0215 - binary_io_u: 0.7741 - val_loss: 0.0606 - val_binary_io_u: 0.5817
# Epoch 49/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0209 - binary_io_u: 0.7801 - val_loss: 0.0583 - val_binary_io_u: 0.5812
# Epoch 50/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0204 - binary_io_u: 0.7852 - val_loss: 0.0581 - val_binary_io_u: 0.5997

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('kde_edtlabel2_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.804543
# Binary IoU = 0.804543
# Binary IoU for class 1 = 0.6297348
# Binary IoU for class 0 = 0.9793513

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 10
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
ax.imshow(y_test[k] > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 674ms/step

# %% [markdown]
# #### EDT3

# %%
kf = 0

data = np.load("../labelmaking/all_scaled_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,1][kf::2]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,1][kf::2]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0][kf::2]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0][kf::2]
y_test = np.expand_dims(y_test, axis=-1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# unet architecture
def conv_block(input, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    x = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation("relu")(x)
    return x


def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = tf.keras.layers.MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(input, skip_features, num_filters):
    x = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(
        input
    )
    x = tf.keras.layers.Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x


def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)
    b1 = conv_block(p4, 1024)
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

# parameters 
input_shape = x_train.shape[1:]
batch_size = 64
learning_rate = 0.001
epochs = 50

model = build_unet(input_shape)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)], 
)

checkpoint_filepath = 'kde_edtlabel_64'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_test, y_test),
    callbacks=[model_checkpoint_callback],
)
# Out:
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# (2390, 128, 128, 1)
# (597, 128, 128, 1)
# 2023-10-06 10:13:30.448512: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.460476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.460625: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.461674: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.461823: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.461955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.873506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.873642: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.873740: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-06 10:13:30.873819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14769 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-10-06 10:13:31.640834: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 156631040 exceeds 10% of free system memory.
# 2023-10-06 10:13:31.829344: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 313262080 exceeds 10% of free system memory.
# 2023-10-06 10:13:32.003781: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 156631040 exceeds 10% of free system memory.
# 2023-10-06 10:13:32.066378: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 313262080 exceeds 10% of free system memory.
# Epoch 1/50
# 2023-10-06 10:13:35.794821: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-10-06 10:13:35.874749: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:13:40.233662: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3125fa00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-06 10:13:40.233682: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Quadro RTX 5000, Compute Capability 7.5
# 2023-10-06 10:13:40.236859: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-06 10:13:40.280300: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-06 10:13:40.317162: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 [==============================] - 51s 798ms/step - loss: 0.2172 - binary_io_u: 0.5622 - val_loss: 24.9877 - val_binary_io_u: 0.0685
# Epoch 2/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0853 - binary_io_u: 0.7366 - val_loss: 0.2928 - val_binary_io_u: 1.0205e-05
# Epoch 3/50
# 38/38 [==============================] - 24s 640ms/step - loss: 0.0633 - binary_io_u: 0.7541 - val_loss: 0.2250 - val_binary_io_u: 0.0000e+00
# Epoch 4/50
# 38/38 [==============================] - 17s 454ms/step - loss: 0.0529 - binary_io_u: 0.7608 - val_loss: 0.2299 - val_binary_io_u: 0.0000e+00
# Epoch 5/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0476 - binary_io_u: 0.7617 - val_loss: 0.1507 - val_binary_io_u: 0.0429
# Epoch 6/50
# 38/38 [==============================] - 24s 645ms/step - loss: 0.0441 - binary_io_u: 0.7625 - val_loss: 0.1104 - val_binary_io_u: 0.3045
# Epoch 7/50
# 38/38 [==============================] - 17s 455ms/step - loss: 0.0416 - binary_io_u: 0.7649 - val_loss: 0.1106 - val_binary_io_u: 0.2666
# Epoch 8/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0395 - binary_io_u: 0.7689 - val_loss: 0.1121 - val_binary_io_u: 0.2409
# Epoch 9/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0382 - binary_io_u: 0.7701 - val_loss: 0.0827 - val_binary_io_u: 0.4945
# Epoch 10/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0371 - binary_io_u: 0.7724 - val_loss: 0.1060 - val_binary_io_u: 0.3373
# Epoch 11/50
# 38/38 [==============================] - 24s 636ms/step - loss: 0.0360 - binary_io_u: 0.7750 - val_loss: 0.0618 - val_binary_io_u: 0.7094
# Epoch 12/50
# 38/38 [==============================] - 25s 652ms/step - loss: 0.0356 - binary_io_u: 0.7756 - val_loss: 0.0576 - val_binary_io_u: 0.7214
# Epoch 13/50
# 38/38 [==============================] - 17s 456ms/step - loss: 0.0351 - binary_io_u: 0.7772 - val_loss: 0.0647 - val_binary_io_u: 0.6265
# Epoch 14/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0347 - binary_io_u: 0.7769 - val_loss: 0.0794 - val_binary_io_u: 0.5553
# Epoch 15/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0341 - binary_io_u: 0.7796 - val_loss: 0.0739 - val_binary_io_u: 0.5446
# Epoch 16/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0336 - binary_io_u: 0.7805 - val_loss: 0.0755 - val_binary_io_u: 0.5843
# Epoch 17/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0330 - binary_io_u: 0.7835 - val_loss: 0.0578 - val_binary_io_u: 0.6820
# Epoch 18/50
# 38/38 [==============================] - 24s 637ms/step - loss: 0.0323 - binary_io_u: 0.7880 - val_loss: 0.0538 - val_binary_io_u: 0.6972
# Epoch 19/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0326 - binary_io_u: 0.7857 - val_loss: 0.0577 - val_binary_io_u: 0.6805
# Epoch 20/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0322 - binary_io_u: 0.7873 - val_loss: 0.0557 - val_binary_io_u: 0.6954
# Epoch 21/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0320 - binary_io_u: 0.7885 - val_loss: 0.0598 - val_binary_io_u: 0.6700
# Epoch 22/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0313 - binary_io_u: 0.7921 - val_loss: 0.0645 - val_binary_io_u: 0.6572
# Epoch 23/50
# 38/38 [==============================] - 24s 644ms/step - loss: 0.0306 - binary_io_u: 0.7956 - val_loss: 0.0535 - val_binary_io_u: 0.7050
# Epoch 24/50
# 38/38 [==============================] - 24s 641ms/step - loss: 0.0304 - binary_io_u: 0.7960 - val_loss: 0.0465 - val_binary_io_u: 0.7378
# Epoch 25/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0300 - binary_io_u: 0.7988 - val_loss: 0.1049 - val_binary_io_u: 0.4463
# Epoch 26/50
# 38/38 [==============================] - 17s 457ms/step - loss: 0.0301 - binary_io_u: 0.7981 - val_loss: 0.0567 - val_binary_io_u: 0.6705
# Epoch 27/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0294 - binary_io_u: 0.8018 - val_loss: 0.0798 - val_binary_io_u: 0.5806
# Epoch 28/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0293 - binary_io_u: 0.8029 - val_loss: 0.0484 - val_binary_io_u: 0.7249
# Epoch 29/50
# 38/38 [==============================] - 17s 458ms/step - loss: 0.0289 - binary_io_u: 0.8045 - val_loss: 0.0897 - val_binary_io_u: 0.5028
# Epoch 30/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0285 - binary_io_u: 0.8071 - val_loss: 0.0547 - val_binary_io_u: 0.6958
# Epoch 31/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0283 - binary_io_u: 0.8081 - val_loss: 0.0545 - val_binary_io_u: 0.6987
# Epoch 32/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0280 - binary_io_u: 0.8099 - val_loss: 0.0577 - val_binary_io_u: 0.6981
# Epoch 33/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0278 - binary_io_u: 0.8106 - val_loss: 0.0508 - val_binary_io_u: 0.7128
# Epoch 34/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0277 - binary_io_u: 0.8107 - val_loss: 0.0845 - val_binary_io_u: 0.5815
# Epoch 35/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0271 - binary_io_u: 0.8152 - val_loss: 0.0559 - val_binary_io_u: 0.7014
# Epoch 36/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0265 - binary_io_u: 0.8188 - val_loss: 0.0570 - val_binary_io_u: 0.6914
# Epoch 37/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0261 - binary_io_u: 0.8215 - val_loss: 0.0640 - val_binary_io_u: 0.6452
# Epoch 38/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0259 - binary_io_u: 0.8217 - val_loss: 0.0704 - val_binary_io_u: 0.6286
# Epoch 39/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0255 - binary_io_u: 0.8246 - val_loss: 0.0627 - val_binary_io_u: 0.6827
# Epoch 40/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0248 - binary_io_u: 0.8290 - val_loss: 0.0732 - val_binary_io_u: 0.6821
# Epoch 41/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0247 - binary_io_u: 0.8287 - val_loss: 0.0598 - val_binary_io_u: 0.6929
# Epoch 42/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0239 - binary_io_u: 0.8341 - val_loss: 0.0588 - val_binary_io_u: 0.7036
# Epoch 43/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0235 - binary_io_u: 0.8369 - val_loss: 0.0602 - val_binary_io_u: 0.6909
# Epoch 44/50
# 38/38 [==============================] - 17s 460ms/step - loss: 0.0228 - binary_io_u: 0.8414 - val_loss: 0.0636 - val_binary_io_u: 0.6879
# Epoch 45/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0223 - binary_io_u: 0.8445 - val_loss: 0.0576 - val_binary_io_u: 0.7060
# Epoch 46/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0223 - binary_io_u: 0.8446 - val_loss: 0.0560 - val_binary_io_u: 0.7177
# Epoch 47/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0211 - binary_io_u: 0.8522 - val_loss: 0.0642 - val_binary_io_u: 0.7076
# Epoch 48/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0204 - binary_io_u: 0.8564 - val_loss: 0.0626 - val_binary_io_u: 0.7030
# Epoch 49/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0206 - binary_io_u: 0.8555 - val_loss: 0.0721 - val_binary_io_u: 0.6798
# Epoch 50/50
# 38/38 [==============================] - 17s 459ms/step - loss: 0.0196 - binary_io_u: 0.8621 - val_loss: 0.0628 - val_binary_io_u: 0.7092

# %%
learning_progress(history)

# %%
# load best val_loss epoch 
best_model = tf.keras.models.load_model('kde_edtlabel_64')

# predict ground probabilities for all test images
y_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
y_pred_thresholded = y_pred > 0.5

# IoU metrics
miou = tf.keras.metrics.MeanIoU(num_classes=2)
miou.update_state(y_pred=y_pred_thresholded, y_true=y_test)

biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0, 1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)

print("Mean IoU =", miou.result().numpy())
print("Binary IoU =", biou.result().numpy())

# only for ground
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 1 =", biou.result().numpy())

# only for non-ground pixel
biou = tf.keras.metrics.BinaryIoU(target_class_ids=[0], threshold=0.5)
biou.update_state(y_pred=y_pred, y_true=y_test)
print("Binary IoU for class 0 =", biou.result().numpy())
# Out:
# 19/19 [==============================] - 4s 63ms/step
# Mean IoU = 0.8582542
# Binary IoU = 0.8582542
# Binary IoU for class 1 = 0.73778534
# Binary IoU for class 0 = 0.978723

# %%
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

k = 10
test_img = x_test[k]
prediction = best_model.predict(np.expand_dims(test_img, 0))[0, :, :, 0]

fig, ax = plt.subplots(figsize=(5,5))
fig.set_dpi(200)
im = ax.imshow(np.abs(test_img[:,:,0]-np.max(test_img[:,:,0])))
ax_divider = make_axes_locatable(ax)
cax = ax_divider.append_axes("right", size="7%", pad="2%")
cb = fig.colorbar(im, cax=cax, label='EDT [m]')
ax.imshow(prediction > 0.5, cmap="magma_r", alpha=0.5);
ax.imshow(y_test[k] > 0.5, cmap="magma_r", alpha=0.5);
# Out:
# 1/1 [==============================] - 1s 668ms/step

# %% [markdown]
# ## extraction

# %%
data = np.load("../labelmaking/all_scaled_binary_train_label_EDT2_0_30726_res64_s5.npz")

edt = data['train'][:,:,:,1]
edt = np.expand_dims(edt, axis=-1)

best_model = tf.keras.models.load_model('kde_64')

train_pred = best_model.predict(edt)
train_pred_thresholded = train_pred > 0.5

np.savez_compressed("../Photon_IoU/all_predicted_KDE_res64_order", pred=train_pred_thresholded)
# Out:
# 187/187 [==============================] - 13s 67ms/step

# %%
# load data and best model

data = np.load("../labelmaking/all_scaled_binary_EDT3_res64_concat_s5.npz")
x_train = data["x_train"][:,:,:,1]
x_train = np.expand_dims(x_train, axis=-1)
x_test = data["x_test"][:,:,:,1]
x_test = np.expand_dims(x_test, axis=-1)
y_train = data["y_train"][:,:,:,0]
y_train = np.expand_dims(y_train, axis=-1)
y_test = data["y_test"][:,:,:,0]
y_test = np.expand_dims(y_test, axis=-1)
best_model = tf.keras.models.load_model('kde_edtlabel3_64')

# prediction images
# predict ground probabilities for all train images
train_pred = best_model.predict(x_train)
# Convert sigmoid probability to classification
train_pred_thresholded = train_pred > 0.5

# predict ground probabilities for all test images
test_pred = best_model.predict(x_test)
# Convert sigmoid probability to classification
test_pred_thresholded = test_pred > 0.5

# load divider indices
ind_test = np.load('../labelmaking/all_concat_64_s5_indices_test.npy')
ind_train = np.load('../labelmaking/all_concat_64_s5_indices_train.npy')
ind_all = np.load('../labelmaking/all_concat_64_s5_indices.npy')

# divide
test_pred_mtns = test_pred_thresholded[:ind_test[0]]
test_pred_fhills = test_pred_thresholded[ind_test[0]:ind_test[1]]
test_pred_plains = test_pred_thresholded[ind_test[1]:]

train_pred_mtns =   train_pred_thresholded[:ind_train[0]]
train_pred_fhills = train_pred_thresholded[ind_train[0]:ind_train[1]]
train_pred_plains = train_pred_thresholded[ind_train[1]:]

# concatenate
all_predicted = np.concatenate((test_pred_mtns, train_pred_mtns, test_pred_fhills, train_pred_fhills, test_pred_plains, train_pred_plains))
print(all_predicted.shape)
# Out:
# 150/150 [==============================] - 10s 67ms/step
# 38/38 [==============================] - 2s 67ms/step
# (5974, 128, 128, 1)

# %%
np.savez_compressed("../Photon_IoU/all_predicted_KDE_edtlabel3_res64", pred=all_predicted)
